# %% [markdown]
# # Visual Genome question generation
# This notebooks aims to filter Visual Genome data to get only specific domain data. The Visual Genome dataset contains objects annotations that we will use to filter our data. The result is images containing objects listed in keywords text file

# %% [markdown]
# ## imports

# %%
# this is normally not used, I did it just in case someone needs to do special tests. I downloaded the files directly in this notebook
# !pip install visual-genome
# Out:
# Requirement already satisfied: visual-genome in /usr/local/lib/python3.6/dist-packages (1.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from visual-genome) (2.18.4)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.6/dist-packages (from visual-genome) (3.38.0)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->visual-genome) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->visual-genome) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->visual-genome) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->visual-genome) (1.22)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from progressbar2->visual-genome) (2.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from progressbar2->visual-genome) (1.11.0)
# Requirement already satisfied: visual-genome in /usr/local/lib/python3.6/dist-packages (1.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from visual-genome) (2.18.4)
# Requirement already satisfied: progressbar2 in /usr/local/lib/python3.6/dist-packages (from visual-genome) (3.38.0)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->visual-genome) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->visual-genome) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->visual-genome) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->visual-genome) (1.22)
# Requirement already satisfied: python-utils>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from progressbar2->visual-genome) (2.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from progressbar2->visual-genome) (1.11.0)

# %%
#import drive, you can word without drive

from google.colab import drive
from visual_genome import api
import json
import seaborn as sbs
import pandas as pd
from itertools import groupby
from collections import Counter
import os
import sys
#from gensim.models import Word2Vec
#import gensim

# %% [markdown]
# ## variables

# %%
#mounting drive path, this is optional
drive_path = '/content/gdrive'
#file containing keywords for filtering images
keywords_file = '/content/gdrive/My Drive/Colab/indoors.txt'
#file containing negative keywords for filtering images
neg_keywords_file = '/content/gdrive/My Drive/Colab/Nindoor.txt'
#download_objects.json
download_objects_path = '/content'
#file where to save image ids
writingPath = '/content/gdrive/My Drive/Colab/VisualGenomeImageIds.txt'
#Download QAs path
download_QAs_path = '/content'
#file where to save Questions Answers. This is the final file you get
save_qas_file = '/content/gdrive/My Drive/Colab/QAs.json'

# %% [markdown]
# ## Mounting Drive (Don't do it if you don't use drive)

# %%
drive.mount(drive_path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## Visual Genome API
# Install a python Visual Genome API that let us interact with The Visual Genome dataset like getting objects in an image....

# %% [markdown]
# ### Download all image Ids
# Download them via API and count them

# %%
ids = api.get_all_image_ids()
c = 0
for i in ids :
  c = c+1
print(c)
# Out:
# 108077

# %% [markdown]
# ## Loading and filtering keywords file
# Remove extra-characters, empty strings and repeated words from keywords. Keywords are name of objects that must be present in the image

# %%
f = open(keywords_file, 'r')
lines = f.readlines()
lines = [x.lower().strip() for x in lines if x.lower().strip() != '']
#remove repeated
lines = list(set(lines))
f.close()

# %% [markdown]
# ##

# %%
g = open(neg_keywords_file, 'r')
Nlines = g.readlines()
Nlines = [x.lower().strip() for x in Nlines if x.lower().strip() != '']
#remove repeated
Nlines = list(set(Nlines))
g.close()
Nlines
# Out:
# ['bus',
#  'sidewalk',
#  'park',
#  'car',
#  'building',
#  'beach',
#  'elephant',
#  'walkway',
#  'sun',
#  'ocean',
#  'street',
#  'city',
#  'motorcycle']

# %% [markdown]
# ## Download objects
# Download objects present in the Visual Genome dataset. The file contains the graph scene of each image in Visual Genome. Each graph scene contains a list of objects and other informations.
# idGraph will contain tupples of (image id, objects present in this image)

# %%
# put objects.json in drive
# !wget -P '$download_objects_path' http://visualgenome.org/static/data/dataset/objects.json.zip
os.chdir(download_objects_path)
# !unzip objects.json
json_path = os.path.join(download_objects_path, 'objects.json')
f = open(json_path,'r')
idGraphs= json.load(f)
f.close()
idGraph = []
for g in idGraphs:
  objs = []
  for obj in g['objects']:
    for name in obj['names']:
      objs.append(name)
  idGraph.append((g['image_id'],objs))
# Out:
# --2019-02-27 18:19:48--  http://visualgenome.org/static/data/dataset/objects.json.zip
# Resolving visualgenome.org (visualgenome.org)... 54.87.32.87
# Connecting to visualgenome.org (visualgenome.org)|54.87.32.87|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55323929 (53M) [application/zip]
# Saving to: ‘/content/objects.json.zip’
#
# objects.json.zip    100%[===================>]  52.76M  16.4MB/s    in 3.7s
#
# 2019-02-27 18:19:51 (14.2 MB/s) - ‘/content/objects.json.zip’ saved [55323929/55323929]
#
# Archive:  objects.json.zip
#   inflating: objects.json

# %% [markdown]
# ### copying idGraph in idObjs (this could be avoided but i don't want to refactor code)

# %%
idObjs = [(id, objects) for (id, objects) in idGraph]

# %%
Nlines
# Out:
# ['bus',
#  'sidewalk',
#  'park',
#  'car',
#  'building',
#  'beach',
#  'elephant',
#  'walkway',
#  'sun',
#  'ocean',
#  'street',
#  'city',
#  'motorcycle']

# %% [markdown]
# ## Filter objects
# Here, we filter objects present in visual genome, we get the objects that are in 'lines' (keywords) and that are not in 'Nlines' (negative keywords).
# idObjsLen is a list of tuples of (image id , list of objects, length of the list of objects). The tuples represent the images that have at least on object that passed the filter.

# %%
idObjsLen = []
for (id, objs) in idObjs:
  objs1 = [obj.lower().strip() for obj in objs]
  s = set(objs1).intersection(lines)
  s2 = set(objs1).intersection(Nlines)
  if (not len(s) == 0) and (len(s2) == 0):
    idObjsLen.append((id, objs,len(s)))

# %%
len(idObjsLen)
# Out:
# 35438

# %% [markdown]
# ### occurences of objects in filtered images
# idObjLen2 is idObjLen sorted by list of objects length, this was done in my case to fill the keyword file with new keywords based when i see some words that has high occurence needed for better filtering

# %%
idObjsLen2 = sorted(idObjsLen, key=lambda tup: tup[2],reverse = True)
#idObjsLen2 = [ i  for i in idObjsLen if i[2] == 1]
idObjsLen2
# Out:
# [(2396305,
#   ['blinds',
#    'blue pot',
#    'book',
#    'books',
#    'bookshelf',
#    'carpet',
#    'coffee table',
#    'couch',
#    'dvd player',
#    'floor',
#    'frame',
#    'frame',
#    'furniture',
#    'glass',
#    'lamp',
#    'laptop',
#    'leaves',
#    'newspaper',
#    'painting',
#    'pillow',
#    'pillow',
#    'rack',
#    'remote',
#    'room',
#    'rug',
#    'shade',
#    'shades',
#    'shelf',
#    'sofa',
#    'sofa',
#    'table',
#    'vase',
#    'view',
#    'wall',
#    'window',
#    'window'],
#   17),
#  (2388981,
#   ['area rug',
#    'backsplash',
#    'bar stools',
#    'bar stools',
#    'bookshelves',
#    'bowl',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'ceiling',
#    'coffee pot',
#    'computer desk',
#    'computer monitor',
#    'counter',
#    'counter',
#    'desk',
#    'faucet',
#    'floor',
#    'fruit',
#    'holder',
#    'kitchen',
#    'knife block',
#    'lighting',
#    'lighting',
#    'lighting',
#    'lighting',
#    'lighting',
#    'microwave',
#    'microwave oven',
#    'oven',
#    'papertowels',
#    'person',
#    'refrigerator',
#    'rug',
#    'shirt',
#    'sink',
#    'stool',
#    'stool',
#    'stools',
#    'stools',
#    'stove',
#    'stove top',
#    'table',
#    'throw rug',
#    'toaster',
#    'woman'],
#   17),
#  (2412143,
#   ['border',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinets',
#    'cabinets',
#    'carpet',
#    'cart',
#    'chair',
#    'clock',
#    'cooler',
#    'cooler',
#    'counter',
#    'curtains',
#    'curtains',
#    'curtains',
#    'curtains',
#    'dish strainer',
#    'dishwasher',
#    'door',
#    'door',
#    'door',
#    'door',
#    'door',
#    'door',
#    'floor',
#    'floor',
#    'floor',
#    'food',
#    'ingredients',
#    'kettle',
#    'kitchen',
#    'microwave',
#    'mobile shelf',
#    'outlet',
#    'pan',
#    'pans',
#    'pot',
#    'red tablecloth',
#    'rug',
#    'runner',
#    'shelf',
#    'shelf',
#    'shelf',
#    'sink',
#    'stove',
#    'table',
#    'utensils',
#    'wall',
#    'wall',
#    'water dispenser',
#    'window',
#    'window',
#    'window',
#    'window'],
#   17),
#  (2409377,
#   ['board',
#    'case',
#    'cd',
#    'cellphone',
#    'chair',
#    'clock',
#    'cords',
#    'cubicle',
#    'cup',
#    'cushion',
#    'desk',
#    'disk',
#    'frames',
#    'glass',
#    'hard drive',
#    'keyboard',
#    'landline',
#    'laptop',
#    'monitor',
#    'mouse',
#    'mug',
#    'organizer',
#    'pad',
#    'paper',
#    'photographs',
#    'room',
#    'shelf',
#    'telephone',
#    'toy',
#    'wall'],
#   15),
#  (2408706,
#   ['boat',
#    'bottle',
#    'cabinet',
#    'cabinets',
#    'cart',
#    'chair',
#    'clock',
#    'coffee cup',
#    'coffee maker',
#    'control panel',
#    'cross',
#    'desk',
#    'dishes',
#    'doors',
#    'drawers',
#    'flour',
#    'fridge',
#    'handle',
#    'jar',
#    'kitchen',
#    'knobs',
#    'lamp shade',
#    'lights',
#    'microwave',
#    'oven',
#    'picture',
#    'pictures',
#    'plates',
#    'posters',
#    'pots',
#    'refrigerator',
#    'shelves',
#    'sink',
#    'spoons',
#    'stand',
#    'stove',
#    'stove top',
#    'table',
#    'towel',
#    'tubes',
#    'unit',
#    'wall'],
#   15),
#  (2392938,
#   ['banana',
#    'basket',
#    'cabinet',
#    'cabinet',
#    'ceiling',
#    'chair',
#    'chairs',
#    'counter',
#    'fan',
#    'floor',
#    'fruit',
#    'glass',
#    'hands',
#    'kitchen',
#    'mat',
#    'microwave',
#    'mullions',
#    'oven',
#    'pineapple',
#    'refrigerator',
#    'shirt',
#    'sink',
#    'table',
#    'trash can',
#    'vent',
#    'wall',
#    'window',
#    'woman'],
#   15),
#  (2363897,
#   ['art',
#    'bags',
#    'bags',
#    'band',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'bookcase',
#    'books',
#    'bookshelf',
#    'ceiling',
#    'ceiling fan',
#    'chair',
#    'coats',
#    'computer',
#    'decal',
#    'desk',
#    'door',
#    'doorknob',
#    'double lights',
#    'fixture',
#    'floor',
#    'floor',
#    'footstool',
#    'hat',
#    'hook',
#    'jacket',
#    'jacket',
#    'large shelving',
#    'light',
#    'light',
#    'man',
#    'ottoman',
#    'painted red',
#    'painting',
#    'pipe',
#    'poster',
#    'records',
#    'rug',
#    'screen',
#    'seat',
#    'shelves',
#    'strip',
#    'tv guide',
#    'wall',
#    'wall',
#    'windows'],
#   15),
#  (2360794,
#   ['bowl',
#    'cabinet',
#    'ceiling',
#    'counter',
#    'cup',
#    'dishwasher',
#    'door',
#    'drawer',
#    'floor',
#    'freezer',
#    'fridge',
#    'kettle',
#    'kitchen',
#    'lights',
#    'microwave',
#    'oven',
#    'pantry',
#    'picture',
#    'plaques',
#    'shelves',
#    'sink',
#    'stove',
#    'teapot',
#    'towel',
#    'utensils',
#    'vent',
#    'wall',
#    'window'],
#   15),
#  (2349426,
#   ['basket',
#    'basket',
#    'bowl',
#    'bowls',
#    'box',
#    'chair',
#    'chair',
#    'countertop',
#    'cup',
#    'cup',
#    'cup',
#    'cup',
#    'cup',
#    'cup',
#    'curtain',
#    'faucet',
#    'fire extinguisher',
#    'floor',
#    'handle',
#    'handle',
#    'hanger',
#    'holder',
#    'hook',
#    'hook',
#    'hook',
#    'hook',
#    'hook',
#    'hook',
#    'kitchen',
#    'knife',
#    'microwave',
#    'oven',
#    'paper towel holder',
#    'plates',
#    'plates',
#    'plates',
#    'plates',
#    'rack',
#    'refrigerator',
#    'shelf',
#    'shelf',
#    'shelf',
#    'shelf',
#    'sink',
#    'socket',
#    'table',
#    'tile',
#    'toaster',
#    'top',
#    'towel',
#    'towel',
#    'utensil',
#    'utensil',
#    'utensil',
#    'utensil',
#    'utensil',
#    'wall'],
#   15),
#  (2414462,
#   ['cabinet doors',
#    'ceiling',
#    'coffee maker',
#    'coffee pot',
#    'containers',
#    'counter top',
#    'cutting board',
#    'dispenser',
#    'door',
#    'faucet',
#    'flat top',
#    'floor',
#    'frame',
#    'glass',
#    'handles',
#    'holder',
#    'island',
#    'jar',
#    'kitchen',
#    'lanterns',
#    'lighting',
#    'oven',
#    'panels',
#    'plant',
#    'pot',
#    'refrigerator',
#    'shelf',
#    'shelves',
#    'sink',
#    'stove',
#    'tile',
#    'toaster',
#    'wall',
#    'window',
#    'windows',
#    'wine'],
#   15),
#  (2411681,
#   ['back',
#    'bowl',
#    'cabinet',
#    'cabinet',
#    'cabinetry',
#    'ceiling',
#    'chair',
#    'cord',
#    'counter',
#    'countertop',
#    'countertops',
#    'dials',
#    'doors',
#    'floor',
#    'fridge',
#    'glass',
#    'glasswear',
#    'granite',
#    'kitchen',
#    'knob',
#    'laptop',
#    'light',
#    'light',
#    'light',
#    'lighting',
#    'microwave',
#    'mixer',
#    'molding',
#    'pan',
#    'range',
#    'refrigerator',
#    'seat',
#    'shoot',
#    'sink',
#    'source',
#    'stove',
#    'table',
#    'toaster',
#    'umbrella',
#    'umbrellag',
#    'view',
#    'wall',
#    'window',
#    'wood'],
#   15),
#  (2394506,
#   ['back',
#    'bag',
#    'books',
#    'cabinet',
#    'carpet',
#    'ceiling',
#    'chair',
#    'chairs',
#    'corner',
#    'couch',
#    'curtain',
#    'curtains',
#    'device',
#    'door',
#    'floor',
#    'leg',
#    'light',
#    'painting',
#    'room',
#    'shelf',
#    'shelf',
#    'shelf',
#    'shelves',
#    'table',
#    'trim',
#    'tv',
#    'wall',
#    'window'],
#   14),
#  (2391930,
#   ['basket',
#    'box',
#    'candle',
#    'candle',
#    'candle',
#    'candlestick',
#    'candlestick',
#    'candlestick',
#    'ceiling',
#    'centerpiece',
#    'chair',
#    'coffee table',
#    'corner',
#    'corner',
#    'couch',
#    'curtain',
#    'curtains',
#    'decoration',
#    'fan',
#    'fireplace',
#    'floor',
#    'foot',
#    'lap',
#    'laptop',
#    'legs',
#    'light',
#    'light',
#    'light',
#    'man',
#    'mantel',
#    'mirror',
#    'pair',
#    'reeds',
#    'rod',
#    'screen',
#    'shoes',
#    'side table',
#    'squash',
#    'surround',
#    'table',
#    'tv',
#    'tv stand',
#    'vase',
#    'vgetables',
#    'wall'],
#   14),
#  (2373694,
#   ['bar',
#    'blade',
#    'blade',
#    'blade',
#    'blade',
#    'ceiling',
#    'ceiling',
#    'ceiling fan',
#    'chair',
#    'chair',
#    'couch',
#    'counter',
#    'door',
#    'door',
#    'doorway',
#    'doorway',
#    'doorway',
#    'exhaust system',
#    'fan',
#    'floor',
#    'furniture',
#    'furniture',
#    'furniture',
#    'furniture',
#    'furniture',
#    'ground',
#    'hallway',
#    'house',
#    'island',
#    'kitchen',
#    'kitchen',
#    'kitchen',
#    'light',
#    'light',
#    'light',
#    'light',
#    'light',
#    'light',
#    'lighting',
#    'living room',
#    'ottoman',
#    'ottoman',
#    'ottoman',
#    'pillow',
#    'pillows',
#    'refrigerator',
#    'room',
#    'sofa',
#    'sofa',
#    'sofa',
#    'stool',
#    'stool',
#    'stove',
#    'stove',
#    'table',
#    'throw pillow',
#    'vent',
#    'wall',
#    'wall'],
#   14),
#  (2369068,
#   ['back',
#    'blinds',
#    'bottom',
#    'brick',
#    'bulb',
#    'bulb',
#    'bulb',
#    'carpet',
#    'ceiling',
#    'chair',
#    'chair',
#    'chair',
#    'chairs',
#    'coffee',
#    'counter',
#    'cup',
#    'dishwasher',
#    'door',
#    'edge',
#    'fire',
#    'floor',
#    'fridge',
#    'head',
#    'head',
#    'head',
#    'jacket',
#    'kitchen',
#    'kitchenette',
#    'lamp',
#    'lettering',
#    'lights',
#    'metal',
#    'microwave',
#    'oven',
#    'paper',
#    'pattern',
#    'place',
#    'plate',
#    'pole',
#    'pot',
#    'room',
#    'row',
#    'set',
#    'steel',
#    'stone',
#    'stove',
#    'style',
#    'table',
#    'top',
#    'top',
#    'tree',
#    'wall',
#    'wall',
#    'window',
#    'window',
#    'window'],
#   14),
#  (2366815,
#   ['block',
#    'board',
#    'cabinet',
#    'cabinets',
#    'cabinets',
#    'cabinets',
#    'clock',
#    'counter',
#    'counter',
#    'daytime',
#    'dishwasher',
#    'door',
#    'door',
#    'drawer',
#    'faucet',
#    'floor',
#    'jar',
#    'kitchen',
#    'knives',
#    'knobs',
#    'knobs',
#    'mat',
#    'microwave',
#    'oven',
#    'refrigerator',
#    'shelf',
#    'shelves',
#    'sink',
#    'spices',
#    'stove',
#    'sunlight',
#    'tap',
#    'tile',
#    'tile',
#    'towels',
#    'wall',
#    'window'],
#   14),
#  (2413282,
#   ['brick',
#    'brown',
#    'burner',
#    'burners',
#    'cabinet',
#    'ceiling',
#    'chair',
#    'containers',
#    'counter',
#    'cupboard',
#    'curtains',
#    'door',
#    'floor',
#    'flowers',
#    'food',
#    'fringe',
#    'glass',
#    'grey',
#    'handles',
#    'hanging',
#    'hood',
#    'light',
#    'microwave',
#    'oven',
#    'patterns',
#    'plants',
#    'print',
#    'refrigerator',
#    'rug',
#    'shelves',
#    'short',
#    'sill',
#    'spindles',
#    'stove',
#    'table',
#    'toaster',
#    'two',
#    'various',
#    'wall',
#    'white',
#    'wooden'],
#   14),
#  (4888,
#   ['bouquet',
#    'candle',
#    'ceiling',
#    'chair',
#    'chair',
#    'chair',
#    'chandelier',
#    'coffee maker',
#    'counter',
#    'counter',
#    'counter',
#    'cup',
#    'cupboard',
#    'cupboard',
#    'cushion',
#    'dish',
#    'doorway',
#    'floor',
#    'flower',
#    'flower',
#    'flower',
#    'flower',
#    'flower',
#    'frame',
#    'fridge',
#    'holder',
#    'kitchen',
#    'light',
#    'light',
#    'microwave',
#    'napkin',
#    'oven',
#    'pan',
#    'statue',
#    'stovetop',
#    'table',
#    'vase'],
#   13),
#  (150396,
#   ['bookcase',
#    'books',
#    'books',
#    'cabinets',
#    'candle',
#    'carpet',
#    'chair',
#    'couch',
#    'counter',
#    'cushion',
#    'desk',
#    'entrance',
#    'food',
#    'frame',
#    'holder',
#    'kitchen',
#    'kitchen chair',
#    'lamp',
#    'light',
#    'microwave',
#    'object',
#    'ottoman',
#    'picture',
#    'room',
#    'shelves',
#    'switch',
#    'table',
#    'track lighting',
#    'tray',
#    'vent'],
#   13),
#  (713692,
#   ['bad object',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'books',
#    'books',
#    'bookshelf',
#    'chair',
#    'clock',
#    'clock',
#    'cup',
#    'cup',
#    'end table',
#    'floor',
#    'glasses',
#    'hearth',
#    'man',
#    'man',
#    'man',
#    'mantle',
#    'newspaper',
#    'newspaper',
#    'pencils',
#    'photo',
#    'shelf',
#    'shelf',
#    'shelf',
#    'sofa',
#    'table',
#    'tools',
#    'toy',
#    'toy horse',
#    'toys',
#    'wall'],
#   13),
#  (2410444,
#   ["'turkerworkers",
#    'air freshener',
#    'artwork',
#    'bag',
#    'bar',
#    'bathroom',
#    'bench [?]',
#    'butt end',
#    'cabinet',
#    'cellphone',
#    'circular top',
#    'cover',
#    'cow',
#    'donuts',
#    'doorway',
#    'expression',
#    'faucet',
#    'floor',
#    'frame',
#    'frame',
#    'hair',
#    'hamper',
#    'hand towel',
#    'heads cut off',
#    'kleenex',
#    'kleenex dispenser',
#    'lid',
#    'lid',
#    'liner',
#    'lining',
#    'lively objects',
#    'lysol',
#    'man',
#    'mirror',
#    'painting',
#    'painting',
#    'painting',
#    'painting',
#    'painting',
#    'people',
#    'pipe',
#    'reflection',
#    'scale',
#    'seat',
#    'selfie',
#    'selfie-taker',
#    'shirt',
#    'short sleeve',
#    'shower',
#    'sink',
#    'soap',
#    'soap dispenser',
#    'stack',
#    'stack',
#    'stacks',
#    'tag',
#    'tag',
#    'tag',
#    'tile',
#    'tile',
#    'tile',
#    'tile',
#    'tile',
#    'tiles',
#    'tissue',
#    'toilet',
#    'toilet tank',
#    'toilet tank',
#    'towel',
#    'towel',
#    'towel',
#    'towels',
#    'towels',
#    'wall',
#    'wastebasket'],
#   13),
#  (2408505,
#   ['basket',
#    'blanket',
#    'blankets',
#    'carpet',
#    'chair',
#    'chair',
#    'chair',
#    'chair',
#    'clock',
#    'curtains',
#    'cushion',
#    'cushion',
#    'cushion',
#    'dish towel',
#    'doorway',
#    'floor tiles',
#    'flowers',
#    'kitchen',
#    'outside',
#    'oven',
#    'picture',
#    'picture',
#    'pictures',
#    'pillow',
#    'pillow',
#    'placemat',
#    'placemat',
#    'remote control',
#    'room',
#    'rug',
#    'sofa',
#    'stove',
#    'stove top',
#    'table',
#    'table',
#    'vase',
#    'wall',
#    'wall',
#    'window'],
#   13),
#  (2403699,
#   ['bulletin board',
#    'ceiling',
#    'chair',
#    'clock',
#    'container',
#    'cupboard',
#    'dishes',
#    'dispenser',
#    'door',
#    'fan',
#    'faucet',
#    'floor',
#    'handles',
#    'irons',
#    'kettle',
#    'kitchen',
#    'knobs',
#    'lights',
#    'mat',
#    'refrigerator',
#    'sink',
#    'stove',
#    'table',
#    'tile',
#    'wall',
#    'wallpaper'],
#   13),
#  (2398711,
#   ['basket',
#    'blender',
#    'cabinets',
#    'carpet',
#    'ceiling',
#    'clock',
#    'countertop',
#    'countertop',
#    'curtain',
#    'curtain',
#    'cushion',
#    'door',
#    'drapes',
#    'drawer',
#    'fruit',
#    'hands',
#    'kitchen',
#    'lamp shade',
#    'light',
#    'light',
#    'microwave',
#    'refrigerator',
#    'sink',
#    'stool',
#    'television',
#    'toaster',
#    'window'],
#   13),
#  (2397798,
#   ['blanket',
#    'blinds',
#    'blinds',
#    'blinds',
#    'blinds',
#    'ceiling',
#    'chair',
#    'chair',
#    'chest',
#    'clock',
#    'coffee table',
#    'couch',
#    'door',
#    'floor',
#    'frame',
#    'glass',
#    'lamp',
#    'light',
#    'light',
#    'love seat',
#    'ottoman',
#    'pillow',
#    'pillow',
#    'pillow',
#    'pillow',
#    'pillow',
#    'plant',
#    'plant',
#    'plant',
#    'porch',
#    'pot',
#    'pot',
#    'pot',
#    'railing',
#    'room',
#    'rug',
#    'table',
#    'television',
#    'trees',
#    'trim',
#    'trim',
#    'trim',
#    'wall',
#    'wall',
#    'wall',
#    'window',
#    'window',
#    'window',
#    'window',
#    'window'],
#   13),
#  (2394699,
#   ['bathroom tiles',
#    'bathwash bottle',
#    'bathwash bottle',
#    'cabinet',
#    'cabinet',
#    'circle',
#    'cup',
#    'cup',
#    'curtain',
#    'dispenser',
#    'doors',
#    'faucet',
#    'floor',
#    'frame',
#    'handwash',
#    'kitchen sink',
#    'ledge',
#    'mirror',
#    'rod',
#    'rug',
#    'shower',
#    'sink',
#    'soap',
#    'soap holder',
#    'tile',
#    'toilet',
#    'toilet tank',
#    'toothbrushes',
#    'tub',
#    'wall',
#    'window'],
#   13),
#  (2394627,
#   ['alarm clock',
#    'art work',
#    'bag',
#    'bag',
#    'books',
#    'box',
#    'cell phone',
#    'cereal box',
#    'cereal box',
#    'desk',
#    'desk chair',
#    'digits',
#    'floor',
#    'grey back',
#    'grey seat',
#    'holder',
#    'laptop',
#    'microwave',
#    'printer',
#    'refrigerator',
#    'scissors',
#    'shelf',
#    'shelf',
#    'telephone',
#    'tissue',
#    'wall'],
#   13),
#  (2386107,
#   ['arm chair',
#    'book',
#    'brown trim',
#    'carpet',
#    'chair',
#    'chair',
#    'chairs',
#    'chandelier',
#    'coasters',
#    'coffee table',
#    'desk',
#    'dining room chair',
#    'door',
#    'floor',
#    'lamp',
#    'magazine',
#    'picture',
#    'pillow',
#    'pillows',
#    'refrigerator',
#    'room',
#    'sofa',
#    'table',
#    'telephone',
#    'tv remote control',
#    'wall',
#    'window'],
#   13),
#  (2375183,
#   ['artwork',
#    'basket',
#    'cabinet',
#    'cabinets',
#    'coffee maker',
#    'corner',
#    'counter',
#    'counter top',
#    'cupboard',
#    'desk',
#    'dishwasher',
#    'door',
#    'door',
#    'door',
#    'drawer',
#    'faucet',
#    'floor',
#    'frame',
#    'handle',
#    'holder',
#    'kitchen',
#    'lamp',
#    'lights',
#    'microwave',
#    'mirror',
#    'outlet',
#    'outlet',
#    'oven',
#    'paper towels',
#    'picture',
#    'refrigerator',
#    'rug',
#    'sink',
#    'vase',
#    'vase',
#    'wall'],
#   13),
#  (2370193,
#   ['basket',
#    'books',
#    'bookshelf',
#    'chair',
#    'computer',
#    'computer screen',
#    'container',
#    'container',
#    'cords',
#    'cup',
#    'desk',
#    'disks',
#    'drawers',
#    'dresser',
#    'floor',
#    'frame',
#    'handles',
#    'lamp',
#    'lamp',
#    'monitor',
#    'organizer',
#    'picture',
#    'picture',
#    'picture',
#    'pole',
#    'power strip',
#    'rug',
#    'shelf',
#    'speakers',
#    'stool',
#    'storage area',
#    'storage area',
#    'stripe',
#    'table',
#    'trash',
#    'wall'],
#   13),
#  (2364335,
#   ['cabinet',
#    'cabinet',
#    'cabinet handle',
#    'chair',
#    'counter',
#    'curtain',
#    'door',
#    'drawer',
#    'dry erase board',
#    'faucet',
#    'floor',
#    'freezer',
#    'fridge',
#    'handle',
#    'kettle',
#    'kitchen',
#    'knob',
#    'lock',
#    'oven',
#    'pants',
#    'plastic bag',
#    'roll of paper',
#    'shelf',
#    'shelf support',
#    'shelf support',
#    'sink',
#    'stove',
#    'sunlight',
#    'sweater',
#    'table',
#    'table cloth',
#    'trash can',
#    'wall',
#    'window',
#    'window',
#    'woman'],
#   13),
#  (2361685,
#   ['bookcase',
#    'bookcase',
#    'bookcase',
#    'books',
#    'books',
#    'books',
#    'bookshelf',
#    'candelabras',
#    'candle',
#    'candle',
#    'ceiling',
#    'chairs',
#    'chandelier',
#    'cloth',
#    'coffee table',
#    'corner',
#    'couch',
#    'decor',
#    'dining room',
#    'dining table',
#    'doorway',
#    'floor',
#    'frame',
#    'furniture',
#    'furniture',
#    'furniture',
#    'furniture',
#    'furniture',
#    'green tablecloth',
#    'holder',
#    'holder',
#    'knick knacks',
#    'knick knacks',
#    'knick knacks',
#    'knick knacks',
#    'knick knacks',
#    'lamp',
#    'light',
#    'light',
#    'light',
#    'lights',
#    'lights',
#    'painting',
#    'painting',
#    'picture',
#    'pillow',
#    'pillows',
#    'pillows',
#    'print',
#    'rug',
#    'shelves',
#    'table',
#    'wall'],
#   13),
#  (2353463,
#   ['basket',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'books',
#    'bookshelf',
#    'bookshelf',
#    'bookshelf',
#    'bookshelf',
#    'bookshelf',
#    'bookshelf',
#    'bookshelves',
#    'chair',
#    'computer monitor',
#    'computer monitor',
#    'computer monitor',
#    'computer monitor',
#    'couch',
#    'cushions',
#    'cushions',
#    'cushions',
#    'cushions',
#    'ground',
#    'ground',
#    'ground',
#    'ground',
#    'lamp',
#    'lamp',
#    'lampshade',
#    'lampshade',
#    'living room',
#    'monitor',
#    'monitor',
#    'monitor',
#    'monitors',
#    'recliner',
#    'red sofapillow',
#    'red sofapillow',
#    'red sofapillow',
#    'red sofapillow',
#    'shelf',
#    'shelf',
#    'shelf',
#    'shelf',
#    'shelf',
#    'shelf',
#    'shelves',
#    'shelves',
#    'sofa',
#    'sofa',
#    'sofa pillow',
#    'stack',
#    'table',
#    'table',
#    'table lamp'],
#   13),
#  (2351480,
#   ['artwork',
#    'bag',
#    'books',
#    'ceiling',
#    'chair',
#    'chairs',
#    'corner',
#    'cup',
#    'curtain',
#    'display',
#    'floor',
#    'freezer',
#    'ground',
#    'kitchen',
#    'kitchen table',
#    'lamp',
#    'lamp',
#    'painting',
#    'painting',
#    'radiator',
#    'rug',
#    'shelf',
#    'table',
#    'wall',
#    'white square',
#    'white square',
#    'white square',
#    'white square',
#    'white square',
#    'window'],
#   13),
#  (2351090,
#   ['back',
#    'back',
#    'back',
#    'book',
#    'book',
#    'book',
#    'books',
#    'books',
#    'bookshelf',
#    'bookshelf',
#    'bottom shelf',
#    'chair',
#    'chair',
#    'chair',
#    'chairs',
#    'desk',
#    'floor',
#    'floor',
#    'floor',
#    'flooring',
#    'ladle',
#    'leg',
#    'leg',
#    'leg',
#    'leg',
#    'reflection',
#    'room',
#    'scoop',
#    'scooper',
#    'shelf',
#    'silverware',
#    'spaghetti spoon',
#    'spatula',
#    'spoon',
#    'spoon',
#    'spoon',
#    'spoon',
#    'spoon',
#    'spoon',
#    'spoon',
#    'spoon',
#    'spoon',
#    'spoon',
#    'spoon',
#    'spoons',
#    'spoons',
#    'strainer',
#    'table',
#    'table',
#    'top shelf',
#    'utensils',
#    'utensils',
#    'wall',
#    'wall',
#    'wooden ladel',
#    'wooden spoon',
#    'wooden tool',
#    'wooden tool',
#    'wooden tool',
#    'wooden tool'],
#   13),
#  (2347683,
#   ['blanket',
#    'ceiling',
#    'chair',
#    'chairs',
#    'chandelier',
#    'coffee table',
#    'cup',
#    'end table',
#    'flip flops',
#    'floor',
#    'floor lamp',
#    'girl',
#    'girl',
#    'glasses',
#    'kitchen',
#    'laptop',
#    'lights',
#    'microwave',
#    'plants',
#    'poster',
#    'remote control',
#    'shade',
#    'sofa',
#    'table lamp',
#    'tumbler',
#    'white shade'],
#   13),
#  (2341547,
#   ['air conditioner',
#    'bathroom',
#    'black belt',
#    'cover',
#    'curtains',
#    'dispenser',
#    'fan',
#    'faucet',
#    'floor',
#    'holder',
#    'lid',
#    'mirror',
#    'missing tiles',
#    'mop',
#    'paper',
#    'paper',
#    'plunger',
#    'reflection',
#    'roll',
#    'seat',
#    'shower',
#    'shower curtain',
#    'shower curtain',
#    'shower head',
#    'sink',
#    'soap holder',
#    'tank',
#    'tile',
#    'toilet',
#    'toilet paper',
#    'toilet seat',
#    'toilet seat',
#    'unit',
#    'wall'],
#   13),
#  (2339347,
#   ['area rug',
#    'arm chair',
#    'armchair',
#    'brown sofa',
#    'candle',
#    'carpeted floor',
#    'chair',
#    'coffee table',
#    'couch',
#    'couch',
#    'dark frame',
#    'floor',
#    'gate',
#    'glass',
#    'glass',
#    'graphic',
#    'handle',
#    'holder',
#    'loveseat',
#    'outside',
#    'painting',
#    'painting, wall',
#    'persian rug',
#    'picture',
#    'pillow',
#    'pillow',
#    'pillow',
#    'pillow',
#    'pillow',
#    'pillow',
#    'pillow',
#    'pillows',
#    'room',
#    'rug',
#    'sofa',
#    'sofa',
#    'table',
#    'television',
#    'trunk',
#    'view',
#    'wall',
#    'wall',
#    'white couch',
#    'white couch',
#    'window',
#    'wine glass',
#    'wine glass',
#    'wood chest'],
#   13),
#  (2335794,
#   ['basket',
#    'basket',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinets',
#    'chair',
#    'chair',
#    'chairs',
#    'clock',
#    'clock',
#    'counter',
#    'counter',
#    'counter top',
#    'counter top',
#    'curtains',
#    'dessert pan',
#    'dining table',
#    'dishwashing liquid',
#    'door',
#    'door',
#    'door',
#    'door',
#    'door',
#    'drawer',
#    'faucet',
#    'ground',
#    'handle',
#    'ice maker',
#    'ipad',
#    'kitchen',
#    'kitchen ceiling',
#    'laptop',
#    'lighting fixture',
#    'lights',
#    'monitor',
#    'refrigerator',
#    'sink',
#    'sink area',
#    'sink faucet',
#    'stove',
#    'table',
#    'table set',
#    'toaster',
#    'wall',
#    'window'],
#   13),
#  (2322021,
#   ['bar',
#    'bathroom',
#    'box',
#    'curtain',
#    'door',
#    'faucet',
#    'floor',
#    'flower',
#    'frame',
#    'handle',
#    'hook',
#    'lid',
#    'mat',
#    'mat',
#    'mirror',
#    'picture',
#    'robe',
#    'rug',
#    'rug',
#    'shower',
#    'shower head',
#    'sink',
#    'soap',
#    'soap dish',
#    'strip',
#    'stripe',
#    'tile',
#    'tissue',
#    'toilet',
#    'toilet tank',
#    'towel',
#    'tub',
#    'window'],
#   13),
#  (2319041,
#   ['armchairs',
#    'armchairs',
#    'bench',
#    'bust',
#    'cabinet',
#    'carpet',
#    'ceiling',
#    'chandelier',
#    'china cabinet',
#    'coffee table',
#    'couch',
#    'curtains',
#    'cushion',
#    'cushion',
#    'cushion',
#    'designs',
#    'doorway',
#    'drapes',
#    'fireplace tools',
#    'frame',
#    'glass',
#    'glass',
#    'glass',
#    'glass doors',
#    'gold curtains',
#    'lamp',
#    'living room',
#    'mirror',
#    'peacock',
#    'piano',
#    'picture',
#    'reflection',
#    'shade',
#    'shelf',
#    'stained glass',
#    'stained glass',
#    'television',
#    'wall',
#    'wall',
#    'wall',
#    'wall',
#    'wall',
#    'way',
#    'window',
#    'window',
#    'window',
#    'window'],
#   13),
#  (2317970,
#   ['block',
#    'bottle',
#    'burner',
#    'burner',
#    'burner',
#    'burner',
#    'cabient',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinets',
#    'ceiling',
#    'container',
#    'counter',
#    'counter',
#    'cup',
#    'cupboards',
#    'cupboards',
#    'curtain',
#    'door',
#    'door',
#    'door',
#    'drawer',
#    'drawer handle',
#    'faucet',
#    'floor',
#    'frame',
#    'frame',
#    'glass',
#    'handle',
#    'handle',
#    'handle',
#    'handle',
#    'handles',
#    'jet',
#    'jet',
#    'jet',
#    'kitchen',
#    'knife',
#    'knife block',
#    'knob',
#    'knob',
#    'light',
#    'oven',
#    'rug',
#    'shelf',
#    'sink',
#    'sink',
#    'stove',
#    'stove top',
#    'switch',
#    'vent',
#    'window',
#    'window'],
#   13),
#  (2317801,
#   ['boxes',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'ceiling',
#    'chairs',
#    'countertop',
#    'dining table',
#    'dishwasher',
#    'floor',
#    'fridge',
#    'ground',
#    'handle',
#    'handles',
#    'kettle',
#    'kitchen',
#    'lamp',
#    'microwave',
#    'oven',
#    'painting',
#    'painting',
#    'refridgerator',
#    'room',
#    'sink',
#    'switches',
#    'table',
#    'table',
#    'tiled counter',
#    'tiled counter',
#    'top',
#    'wall',
#    'white tiles',
#    'window',
#    'yellow walls'],
#   13),
#  (2416973,
#   ['basket',
#    'books',
#    'candle',
#    'chair',
#    'chair',
#    'coffee table',
#    'corner',
#    'couch',
#    'cup',
#    'cushion',
#    'cushions',
#    'door',
#    'door frame',
#    'floor',
#    'foot stool',
#    'frame',
#    'jar',
#    'living room',
#    'objects',
#    'ottoman',
#    'photo frame',
#    'piano',
#    'piano bench',
#    'picture',
#    'picture',
#    'picture',
#    'picture',
#    'pillow',
#    'plant',
#    'room',
#    'seat',
#    'sofa',
#    'stairs',
#    'table',
#    'trim',
#    'vase',
#    'vent',
#    'vine plant',
#    'wall',
#    'wall',
#    'window'],
#   13),
#  (90,
#   ['living room',
#    'wall',
#    'floor',
#    'wall',
#    'rug',
#    'ceiling',
#    'couch',
#    'wall',
#    'table',
#    'frame',
#    'ottomon',
#    'footstool',
#    'bicycle',
#    'shelf',
#    'wall decoration',
#    'stand',
#    'table',
#    'tv',
#    'electric guitar',
#    'stove',
#    'cabinet',
#    'chandelier',
#    'window',
#    'light',
#    'chair',
#    'chair',
#    'cabinet',
#    'ceiling light',
#    'amplifier',
#    'blanket',
#    'sink',
#    'faucet',
#    'television remote'],
#   12),
#  (2411038,
#   ['books',
#    'boy',
#    'chair',
#    'chair',
#    'computer',
#    'couch',
#    'cushions',
#    'desk',
#    'drapes',
#    'floor',
#    'lamp',
#    'lamp',
#    'lamps',
#    'light',
#    'living room',
#    'ottoman',
#    'painting',
#    'patio',
#    'pillow',
#    'pillow',
#    'pillow',
#    'pillows',
#    'pot',
#    'radiator',
#    'room',
#    'rug',
#    'shade',
#    'stool',
#    'table',
#    'table',
#    'tray',
#    'wall',
#    'window'],
#   12),
#  (2409117,
#   ['bath shoes',
#    'bathmat',
#    'bathmat',
#    'bathrobe',
#    'bathroom',
#    'bathtub',
#    'black',
#    'camera or cellphone',
#    'ceiling',
#    'chandelier',
#    'chandelier',
#    "chandelier's light",
#    "chandelier's light",
#    'door',
#    'door',
#    'door',
#    'doorway',
#    'doorway',
#    'double mirror',
#    'drawer',
#    'drawer',
#    'internal chandelier',
#    'intricate interior',
#    'invisible lamp',
#    'invisible lamp',
#    'lamp',
#    'left',
#    'light fixture',
#    'light switch',
#    'lights',
#    'luxury bathroom',
#    'man',
#    'mirror',
#    'mirror',
#    'next room',
#    'next room',
#    'ottoman',
#    'reflection',
#    'right',
#    'right of man',
#    'riser',
#    'riser',
#    'rug',
#    'scene',
#    'seat',
#    'selfie',
#    'shelf',
#    'shelf',
#    'shower',
#    'shower curtain',
#    'sink',
#    'sink',
#    'speaker',
#    'speaker',
#    'speaker',
#    'tile',
#    'tile',
#    'tile',
#    'tile',
#    'tile',
#    'tile',
#    'toilet',
#    'toiletry',
#    'toiletry',
#    'toiletry',
#    'toiletry',
#    'toiletry',
#    'toiletry',
#    'toiletry',
#    'toiletry',
#    'towel',
#    'towel',
#    'towel',
#    'towel',
#    'towel',
#    'towels',
#    'towels',
#    'two sinks',
#    'vanity',
#    'vanity top',
#    'vent',
#    'vent',
#    'wall',
#    'wall',
#    'wall'],
#   12),
#  (2397172,
#   ['arm',
#    'book',
#    'bottle',
#    'cap',
#    'container',
#    'couch',
#    'cushion',
#    'door',
#    'drink',
#    'end table',
#    'fingers',
#    'floor',
#    'hair',
#    'laptop',
#    'laptop',
#    'magazine',
#    'magazines',
#    'man',
#    'picture',
#    'rug',
#    'screen',
#    'shirt',
#    'sock',
#    'speakers',
#    'stand',
#    'stool',
#    'stool cushion',
#    'stools',
#    'table',
#    'television',
#    'wall'],
#   12),
#  (2392636,
#   ['back rest',
#    'books',
#    'books',
#    'cabinet',
#    'chair',
#    'chairs',
#    'chairs',
#    'coffee table',
#    'couch',
#    'curtains',
#    'drawers',
#    'floor',
#    'lamp',
#    'lights',
#    'ottoman',
#    'painting',
#    'pillow',
#    'pillows',
#    'shelf',
#    'table',
#    'table',
#    'television',
#    'wall',
#    'window'],
#   12),
#  (2391005,
#   ['balls',
#    'binder',
#    'book',
#    'books',
#    'books',
#    'cds',
#    'chair',
#    'chair slider',
#    'coffee mug',
#    'crate',
#    'curtains',
#    'desk',
#    'desk lamp',
#    'floor',
#    'glove',
#    'laptop',
#    'monitor',
#    'paper',
#    'papers',
#    'photo',
#    'printer',
#    'sheet',
#    'shelf',
#    'shelf',
#    'shelves',
#    'telephone',
#    'wall'],
#   12),
#  (2387076,
#   ['bathtub',
#    'bottle',
#    'cistern',
#    'counter',
#    'ducky',
#    'faucet',
#    'frame',
#    'glass',
#    'item',
#    'lid',
#    'medicine cabinet',
#    'mirror',
#    'rim',
#    'rod',
#    'shower curtain',
#    'shower head',
#    'shower poof',
#    'shower wall',
#    'sink',
#    'soap holder',
#    'tap',
#    'teapot',
#    'tile',
#    'toilet',
#    'toilet bowl',
#    'toilet paper',
#    'toothbrush',
#    'toothbrush',
#    'window'],
#   12),
#  (2385882,
#   ['bag',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'cabinets',
#    'counter',
#    'counter',
#    'cup',
#    'cup',
#    'dishes',
#    'dishes',
#    'faucet',
#    'food',
#    'hand',
#    'handle',
#    'handle',
#    'handle',
#    'kettle',
#    'kitchen',
#    'knife',
#    'knob',
#    'knob',
#    'microwave',
#    'necklace',
#    'pan',
#    'pan',
#    'pile',
#    'plate',
#    'rolling pin',
#    'shelf',
#    'shirt',
#    'sink',
#    'skirt',
#    'spray can',
#    'stove',
#    'tortilla chips',
#    'towel',
#    'wall',
#    'woman'],
#   12),
#  (2382713,
#   ['bathroom',
#    'bathtub',
#    'bottle',
#    'counter',
#    'curtain rod',
#    'door',
#    'door handle',
#    'faucet',
#    'glass',
#    'glass',
#    'mirror',
#    'rail bar',
#    'seat',
#    'shelf',
#    'shelf',
#    'shower',
#    'shower curtain',
#    'shower curtain',
#    'shower head',
#    'shower wall',
#    'sink',
#    'soap',
#    'tile',
#    'toilet',
#    'toothbrush',
#    'toothpaste',
#    'towel',
#    'towel'],
#   12),
#  (2380948,
#   ['basins',
#    'bathroom',
#    'bathtub',
#    'bowl',
#    'cabinet',
#    'curtain',
#    'dispenser',
#    'faucet',
#    'floor',
#    'frames',
#    'holder',
#    'holder',
#    'holder',
#    'lamp',
#    'ledge',
#    'light',
#    'mirror',
#    'paper',
#    'pictures',
#    'pipe',
#    'ring',
#    'rod',
#    'roof',
#    'roof',
#    'sink',
#    'stand',
#    'stand',
#    'stand',
#    'table',
#    'tassel',
#    'toilet',
#    'towels',
#    'wall',
#    'wall',
#    'wall',
#    'window'],
#   12),
#  (2379904,
#   ['area',
#    'bar',
#    'books',
#    'books',
#    'ceiling',
#    'chair',
#    'chairs',
#    'couch',
#    'couch',
#    'counter',
#    'dining table',
#    'doors',
#    'faucet',
#    'flowers',
#    'fridge',
#    'lights',
#    'lights',
#    'lights',
#    'low back',
#    'painting',
#    'room',
#    'row',
#    'rows',
#    'shelf',
#    'shelves',
#    'stools',
#    'storage',
#    'table',
#    'tv',
#    'vase',
#    'wall'],
#   12),
#  (2376565,
#   ['blinds',
#    'blonde hair',
#    'book',
#    'box',
#    'ceiling',
#    'chair',
#    'chairs',
#    'door',
#    'door frame',
#    'floor',
#    'flowers',
#    'frame',
#    'frames',
#    'glass',
#    'lamp',
#    'lamp',
#    'light',
#    'pants',
#    'picture',
#    'pictures',
#    'plant',
#    'plastic',
#    'pot',
#    'shelf',
#    'shelves',
#    'shirt',
#    'sofa',
#    'stand',
#    'sunglasses',
#    'table',
#    'table',
#    'television',
#    'wall',
#    'window',
#    'woman'],
#   12),
#  (2375823,
#   ['bottle',
#    'bottle',
#    'burner',
#    'burner',
#    'burner',
#    'burner',
#    'buttons',
#    'cabinet door',
#    'cabinets',
#    'cabinets',
#    'canister',
#    'canister',
#    'coffee maker',
#    'dish towel',
#    'dish towel',
#    'dishwasher',
#    'drawer',
#    'floor',
#    'hair',
#    'head',
#    'ice maker',
#    'jar',
#    'kitchen',
#    'man',
#    'microwave',
#    'microwave',
#    'oven',
#    'paper towels',
#    'refrigerator',
#    'shirt',
#    'sink',
#    'soap',
#    'soap',
#    'staircase',
#    'stove',
#    'tie',
#    'utensils'],
#   12),
#  (2373048,
#   ['apartment',
#    'armrests',
#    'carpet',
#    'ceiling',
#    'chair',
#    'chair',
#    'couch',
#    'counter',
#    'cushion',
#    'cushion',
#    'cushion',
#    'desk',
#    'fabric lamp',
#    'fabric lamp',
#    'fan',
#    'floor',
#    'fridge',
#    'hassock',
#    'living room',
#    'mirror',
#    'nails',
#    'panel',
#    'panel',
#    'pillow',
#    'pillow',
#    'shade',
#    'shade',
#    'shelf',
#    'skylight',
#    'skylight',
#    'telephone',
#    'wall',
#    'window'],
#   12),
#  (2368617,
#   ['bed',
#    'bed',
#    'beige carpet',
#    'blanket',
#    'books',
#    'bottle',
#    'carpet',
#    'ceiling',
#    'chair',
#    'clock',
#    'computer',
#    'couch',
#    'desk',
#    'desk',
#    'drawers',
#    'dresser',
#    'floor',
#    'ground',
#    'items',
#    'mattress',
#    'monitor',
#    'photo',
#    'photo',
#    'photo',
#    'pillow',
#    'pillows',
#    'quilt',
#    'room',
#    'shelf',
#    'shelf',
#    'soap',
#    'top',
#    'wall',
#    'wall',
#    'wall'],
#   12),
#  (2366876,
#   ['armchairs',
#    'bulbs',
#    'candle',
#    'candle',
#    'candles',
#    'candles',
#    'candles',
#    'candlesticks',
#    'carpet',
#    'ceiling',
#    'chain',
#    'chair',
#    'chairs',
#    'chandelier',
#    'couch',
#    'cushions',
#    'dishes',
#    'drapes',
#    'drapes',
#    'fan',
#    'figure',
#    'fireplace',
#    'holders',
#    'holders',
#    'holders',
#    'legs',
#    'living room',
#    'picture',
#    'pillow',
#    'pillow',
#    'pillow',
#    'plate',
#    'table',
#    'table',
#    'television',
#    'trees',
#    'wall',
#    'wall',
#    'windows'],
#   12),
#  (2365515,
#   ['bin',
#    'book',
#    'box',
#    'brown',
#    'ceiling',
#    'chair',
#    'containers',
#    'corner',
#    'couch',
#    'covers',
#    'curtain',
#    'curtains',
#    'curtains',
#    'curtains',
#    'door',
#    'fan',
#    'floor',
#    'frame',
#    'framed',
#    'green',
#    'light',
#    'lights',
#    'lights',
#    'poinsetta',
#    'pot',
#    'railing',
#    'room',
#    'rug',
#    'santa',
#    'sofa',
#    'stairway',
#    'storage',
#    'table',
#    'table',
#    'tree',
#    'trees',
#    'wall',
#    'white',
#    'white',
#    'window',
#    'window'],
#   12),
#  (2362647,
#   ['armchair',
#    'ball',
#    'bumble bee',
#    'cat',
#    'ceiling',
#    'chair',
#    'cup',
#    'door',
#    'fence',
#    'floor',
#    'foot rest',
#    'frame',
#    'gate',
#    'ground',
#    'light',
#    'light',
#    'light',
#    'light',
#    'living room',
#    'ottoman',
#    'photos',
#    'photos',
#    'photos',
#    'rug',
#    'screen',
#    'shelves',
#    'shelving unit',
#    'television',
#    'toy',
#    'toy',
#    'tv set',
#    'wall'],
#   12),
#  (2360655,
#   ['blinds',
#    'cds',
#    'chair',
#    'coat',
#    'computer monitor',
#    'computer tower',
#    'container',
#    'cup',
#    'desk',
#    'flyer',
#    'fruit',
#    'glass',
#    'ground',
#    'keyboard',
#    'laptop',
#    'monitor',
#    'monitor',
#    'monitor',
#    'mouse',
#    'office area',
#    'orange',
#    'pens and pencils',
#    'plant',
#    'post it',
#    'post it note',
#    'red wrapping',
#    'shelf',
#    'speakers',
#    'telephone',
#    'wall'],
#   12),
#  (2360065,
#   ['art',
#    'beam',
#    'bottle',
#    'brick',
#    'brick',
#    'brick',
#    'brick',
#    'brick',
#    'chair',
#    'chair',
#    'chair',
#    'clock',
#    'clock face',
#    'coaster',
#    'couch',
#    'dining area',
#    'face',
#    'floor',
#    'glass',
#    'glasses',
#    'green couch',
#    'ground',
#    'hallway',
#    'holder',
#    'hutch',
#    'items',
#    'ledge',
#    'living room',
#    'love seat',
#    'loveseat',
#    'man',
#    'ornament',
#    'painting',
#    'photo',
#    'photo',
#    'photo',
#    'picture',
#    'picture',
#    'picture',
#    'pictures',
#    'plant',
#    'pot',
#    'shelf',
#    'sofa',
#    'speaker',
#    'table',
#    'table',
#    'table',
#    'tree',
#    'wall',
#    'wall',
#    'wall',
#    'wall',
#    'wall',
#    'wall',
#    'wall',
#    'wall',
#    'wall',
#    'window',
#    'yellow wall'],
#   12),
#  (2359478,
#   ['cake',
#    'cake',
#    'cake',
#    'cake',
#    'cake',
#    'cake',
#    'cake',
#    'cake',
#    'carpet',
#    'cell phone',
#    'cellphone',
#    'cloth',
#    'flower',
#    'fork',
#    'glass',
#    'glass',
#    'glass',
#    'glass',
#    'ground',
#    'lettering',
#    'liquid',
#    'mat',
#    'napkin',
#    'pan',
#    'phone',
#    'place mat',
#    'plate',
#    'plate',
#    'platter',
#    'platter',
#    'ribbon',
#    'room',
#    'silver platter',
#    'spoon',
#    'table',
#    'table',
#    'table',
#    'table',
#    'table',
#    'table',
#    'wine glass',
#    'word',
#    'writing'],
#   12),
#  (2359357,
#   ['books',
#    'carpet',
#    'ceiling',
#    'ceiling fan',
#    'clock',
#    'controller',
#    'cupboard',
#    'doll',
#    'dvds',
#    'floor',
#    'game',
#    'green sweater',
#    'ground',
#    'ground',
#    'hand',
#    'jean',
#    'jean',
#    'jeans',
#    'light',
#    'man',
#    'picture',
#    'rack',
#    'room',
#    'screen',
#    'shelf',
#    'shelf',
#    'shelves',
#    'shirt',
#    'snowman',
#    'speaker',
#    'sweater',
#    't-shirt',
#    'televsion',
#    'toy',
#    'toy',
#    'toy',
#    'toy',
#    'toy',
#    'toy',
#    'tree',
#    'video game',
#    'video games',
#    'video player',
#    'watch',
#    'woman'],
#   12),
#  (2359087,
#   ['backsplash',
#    'board',
#    'bottles',
#    'cabinets',
#    'ceiling',
#    'chain',
#    'chair',
#    'chairs',
#    'container',
#    'dishwasher',
#    'doorway',
#    'drawer',
#    'edge',
#    'edge',
#    'edge',
#    'floor',
#    'hook',
#    'kitchen',
#    'legs',
#    'light',
#    'light fixture',
#    'oven',
#    'paper',
#    'part',
#    'part',
#    'part',
#    'part',
#    'part',
#    'part',
#    'plants',
#    'rack',
#    'rug',
#    'shelves',
#    'sink',
#    'splash',
#    'stand',
#    'stove',
#    'table',
#    'tag',
#    'this',
#    'this',
#    'this',
#    'towel',
#    'wall',
#    'window',
#    'window',
#    'windowsill'],
#   12),
#  (2354245,
#   ['bathroom',
#    'bathtub',
#    'bottles',
#    'bottles',
#    'bottles',
#    'ceiling',
#    'chip',
#    'crack',
#    'curtain',
#    'curtain',
#    'edge',
#    'floor',
#    'ground',
#    'item',
#    'item',
#    'item',
#    'item',
#    'items',
#    'items',
#    'ledge',
#    'light',
#    'mat',
#    'mirror',
#    'rod',
#    'rug',
#    'shower',
#    'shower sill',
#    'sink',
#    'sink',
#    'supplies',
#    'table',
#    'tile',
#    'tile',
#    'tiles',
#    'toiletries',
#    'toiletries',
#    'toiletries',
#    'toiletries',
#    'toiletries',
#    'toiletries',
#    'tube',
#    'wall',
#    'wall',
#    'wall',
#    'wall',
#    'window'],
#   12),
#  (2353808,
#   ['black keyboard',
#    'bookcase',
#    'bright screen',
#    'carpet',
#    'case',
#    'cd player',
#    'cds',
#    'cell phone',
#    'controller',
#    'dvd',
#    'flat-screen television',
#    'floor',
#    'keyboard',
#    'keyboard',
#    'laptop',
#    'laptop',
#    'lit screen',
#    'living room',
#    'moon',
#    'mouse',
#    'mouse',
#    'movie',
#    'movie shelf',
#    'movies',
#    'pizza',
#    'platform',
#    'play station',
#    'playstation',
#    'red cd',
#    'remote',
#    'remote',
#    'screen',
#    'shelf',
#    'shelves',
#    'stand',
#    'stand',
#    'system',
#    'television',
#    'tv',
#    'video game',
#    'videogame case',
#    'wall',
#    'wall',
#    'wall',
#    'wall',
#    'walls',
#    'walls',
#    'white screen'],
#   12),
#  (2350547,
#   ['appliance',
#    'basket',
#    'basket on shelves',
#    'black television',
#    'blanket',
#    'books',
#    'books are on the tab',
#    'books on end',
#    'bowl',
#    'brown chair',
#    'candle',
#    'carpet',
#    'coffee table',
#    'couch',
#    'couch in the room',
#    'curtain',
#    'dish',
#    'dish on top of',
#    'dvd',
#    'floor',
#    'framed picture',
#    'image on the wall',
#    'lights',
#    'lights strung',
#    'on the wooden table',
#    'picture is frame',
#    'picture is on the',
#    'room',
#    'shelf',
#    'shelf',
#    'shelf',
#    'shelf',
#    'shelves',
#    'shelves inside',
#    'shelves under',
#    'stack of things',
#    'table',
#    'table has shelves',
#    'this is a curtain',
#    'two dvds',
#    'wall',
#    'window in the room',
#    'windows',
#    'windows'],
#   12),
#  (2344385,
#   ['backsplash',
#    'blanket',
#    'book',
#    'brown chair',
#    'chair',
#    'couch',
#    'dining area',
#    'end table',
#    'floor',
#    'house',
#    'kitchen',
#    'lamp',
#    'lamp shade',
#    'microwave',
#    'painting',
#    'pattern',
#    'picture frame',
#    'refrigerator',
#    'rug',
#    'table',
#    'table',
#    'toilet',
#    'trees',
#    'window',
#    'window'],
#   12),
#  (2343858,
#   ['cabinet',
#    'cabinet',
#    'ceiling',
#    'chair',
#    'chair',
#    'chair',
#    'chair',
#    'chair',
#    'china',
#    'clock',
#    'cloth',
#    'corner',
#    'dishwasher',
#    'door',
#    'doorway',
#    'dryer',
#    'floor',
#    'flower',
#    'flower',
#    'flower',
#    'flower',
#    'flower',
#    'flowers',
#    'ground',
#    'kitchen',
#    'lights',
#    'microwave',
#    'plate',
#    'plate',
#    'plate',
#    'plate',
#    'shelf',
#    'sink',
#    'step',
#    'step',
#    'sunflowers',
#    'table',
#    'table',
#    'table',
#    'table',
#    'table',
#    'table cloth',
#    'table clothe',
#    'tile',
#    'utensils',
#    'wall',
#    'wall',
#    'washer',
#    'washer',
#    'white',
#    'window',
#    'wood'],
#   12),
#  (2342594,
#   ['assorted spoons',
#    'black dishwasher',
#    'bottle',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'canister',
#    'ceiling',
#    'chairs',
#    'clock',
#    'counter',
#    'dish',
#    'faucet',
#    'floor',
#    'green leaves',
#    'kitchen',
#    'kitchen window',
#    'knife',
#    'knife',
#    'knobs',
#    'light',
#    'oven',
#    'paper towels',
#    'plant',
#    'pot',
#    'scissors',
#    'sink',
#    'soap dish',
#    'strip',
#    'table',
#    'toaster oven',
#    'wall',
#    'wood',
#    'yard'],
#   12),
#  (2341485,
#   ['bananas',
#    'box',
#    'bulb',
#    'cabinet',
#    'ceiling',
#    'chair',
#    'chair',
#    'counter',
#    'curtain',
#    'cutout',
#    'dispenser',
#    'door',
#    'door',
#    'door',
#    'door',
#    'door',
#    'door',
#    'door',
#    'door',
#    'freezer',
#    'fridge',
#    'fridge door',
#    'glare',
#    'glass door',
#    'glass door',
#    'holder',
#    'kitchen',
#    'light',
#    'light',
#    'magnet',
#    'pan',
#    'photo',
#    'photo',
#    'room',
#    'shelves',
#    'table',
#    'tile',
#    'tray',
#    'white door',
#    'window'],
#   12),
#  (2335157,
#   ['advertisement',
#    'area rug',
#    'arm',
#    'box',
#    'bric-a-brack',
#    'carpet',
#    'chairs',
#    'clock',
#    "dunkin' donuts",
#    'entertainment center',
#    'floor',
#    'frames',
#    'kitchen',
#    'magnets',
#    'oven',
#    'photographs',
#    'photographs',
#    'refrigerator',
#    'screen',
#    'shelf',
#    'shelves',
#    'shelves',
#    'sofa chair',
#    'speaker',
#    'stand',
#    'television',
#    'tv stand',
#    'wall',
#    'wall'],
#   12),
#  (2330381,
#   ['bag',
#    'basket',
#    'book',
#    'books',
#    'cat',
#    'chest',
#    'couch',
#    'dog',
#    "dog's head",
#    'dresser',
#    'floor',
#    'holder',
#    'lamp',
#    'lights',
#    'magazines',
#    'orange shade',
#    'painting',
#    'pillows',
#    'shelf',
#    'sofa',
#    'sofa pillow',
#    'stand',
#    'table',
#    'television',
#    'wall',
#    'window'],
#   12),
#  (2327399,
#   ['armrests',
#    'armrests',
#    'arrangement',
#    'beam',
#    'bench',
#    'blanket',
#    'book',
#    'cake',
#    'candle',
#    'candles',
#    'candlestick',
#    'ceiling',
#    'chair',
#    'coffee table',
#    'couch',
#    'fabric',
#    'fireplace',
#    'floor',
#    'hanging',
#    'lamp',
#    'leg',
#    'light',
#    'nook',
#    'ottoman',
#    'paper',
#    'pillow',
#    'plant',
#    'plant',
#    'potted',
#    'rolled arm',
#    'rug',
#    'rug',
#    'section',
#    'section',
#    'section',
#    'section',
#    'section',
#    'shade',
#    'shelf',
#    'shelf',
#    'shelf',
#    'table',
#    'table',
#    'table',
#    'trimmings',
#    'vase',
#    'wall'],
#   12),
#  (2324482,
#   ['armrest',
#    'bed',
#    'book',
#    'bottle',
#    'box',
#    'cabinet',
#    'chair',
#    'chairs',
#    'cotton balls',
#    'counter',
#    'desk',
#    'dispenser',
#    'faucet',
#    'floor',
#    'folder',
#    'gloves',
#    'holder',
#    'jar',
#    'kleenex box',
#    'leg',
#    'office',
#    'outlet',
#    'paper',
#    'papertowel dispenser',
#    'patient table',
#    'picture',
#    'sharps container',
#    'sink',
#    'table',
#    'tissues',
#    'top',
#    'top',
#    'wall',
#    'wall',
#    'white paper'],
#   12),
#  (2324144,
#   ['band',
#    'base',
#    'binders',
#    'black keyboard',
#    'board',
#    'board',
#    'bookcase',
#    'books',
#    'bookshelf',
#    'bottle',
#    'computer',
#    'computer mouse',
#    'computer screen',
#    'cup',
#    'desk',
#    'display window',
#    'floor',
#    'frame',
#    'glass',
#    'image',
#    'liquid',
#    'marker',
#    'mess',
#    'monitor',
#    'mouse',
#    'mug',
#    'office',
#    'paper',
#    'papers',
#    'pass-through',
#    'phone',
#    'rubber band',
#    'screen',
#    'shirt',
#    'table',
#    'telephone',
#    'wall',
#    'wires'],
#   12),
#  (2322289,
#   ['ball cap',
#    'basket',
#    'blinds',
#    'book',
#    'cap',
#    'carpet',
#    'chair',
#    'clock',
#    'corner',
#    'curtain',
#    'curtains',
#    'floor',
#    'foot',
#    'girl',
#    'girl',
#    'girl',
#    'girl',
#    'hair',
#    'hand',
#    'head',
#    'head',
#    'head',
#    'knee',
#    'knee',
#    'lamp',
#    'lamp shade',
#    'line',
#    'line',
#    'line',
#    'man',
#    'people',
#    'photo',
#    'room',
#    'rug',
#    'shirt',
#    'stereo',
#    'table',
#    'tables',
#    'television',
#    'wall',
#    'window'],
#   12),
#  (2321952,
#   ['ball',
#    'blanket',
#    'book',
#    'bookcase',
#    'books',
#    'books',
#    'cabinet',
#    'candle',
#    'candle',
#    'candle',
#    'candlesticks',
#    'cat',
#    'ceiling',
#    'chair',
#    'chair',
#    'chair',
#    'couch',
#    'decorations',
#    'decorations',
#    'fan',
#    'floor',
#    'holder',
#    'light',
#    'living room',
#    'monitor',
#    'part',
#    'pillow',
#    'pillow',
#    'plant',
#    'plants',
#    'rug',
#    'sconce',
#    'table',
#    'throw',
#    'top',
#    'wall'],
#   12),
#  (2321443,
#   ['alcove',
#    'book',
#    'books',
#    'bowl',
#    'carpet',
#    'chairs',
#    'chairs',
#    'coffee table',
#    'couch',
#    'curtains',
#    'dining room',
#    'flowers',
#    'flowers',
#    'food',
#    'frame',
#    'fruit platter',
#    'glass top',
#    'jar',
#    'lamp',
#    'lamp',
#    'matting',
#    'painting',
#    'photo',
#    'pillow',
#    'pillow',
#    'pillow',
#    'pot',
#    'room',
#    'roses',
#    'table',
#    'table',
#    'table',
#    'vase',
#    'vase',
#    'vase',
#    'wall',
#    'wall',
#    'wall',
#    'window',
#    'windows',
#    'windows',
#    'windows/curtains'],
#   12),
#  (2320241,
#   ['books',
#    'ceiling',
#    'chair',
#    'curtain',
#    'desk',
#    'floor',
#    'futon',
#    'house',
#    'lamp',
#    'light',
#    'monitor',
#    'pillow',
#    'radiator',
#    'rod',
#    'room',
#    'room',
#    'shelf',
#    'sofa',
#    'table',
#    'wall',
#    'wall',
#    'window'],
#   12),
#  (2316624,
#   ['cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'clock',
#    'cooker',
#    'counter',
#    'counter',
#    'counter',
#    'counter',
#    'counter',
#    'counter',
#    'countertop',
#    'crock pot',
#    'crock pot',
#    'dishtowel',
#    'handle',
#    'handle',
#    'handle',
#    'handle',
#    'handle',
#    'kitchen',
#    'kite',
#    'knob',
#    'knob',
#    'knob',
#    'knobs',
#    'lid',
#    'microwave',
#    'mirror',
#    'mirrored wall',
#    'outlet',
#    'oven',
#    'oven',
#    'oven door',
#    'pot',
#    'pulls',
#    'refrigerator',
#    'sink',
#    'soap',
#    'stove',
#    'stove top',
#    'tea kettle',
#    'toaster',
#    'towel',
#    'wall'],
#   12),
#  (2412644,
#   ['bidet',
#    'cabinet',
#    'commode',
#    'dispenser',
#    'door',
#    'fixtures',
#    'floor',
#    'hamper',
#    'handle',
#    'mirror',
#    'rug',
#    'shelf',
#    'shower curtain',
#    'sink',
#    'soap dish',
#    'tile',
#    'tissue',
#    'tissue holder',
#    'toilet seat',
#    'toilet tissue',
#    'toothpaste box',
#    'towels',
#    'trash can',
#    'wall'],
#   12),
#  (2412012,
#   ['art',
#    'bookcase',
#    'books',
#    'books',
#    'books',
#    'books',
#    'books',
#    'bookshelf',
#    'bowl',
#    'cabinet',
#    'coffee table',
#    'cowboy hat',
#    'entertainment center',
#    'floor',
#    'items',
#    'lamp',
#    'lampshade',
#    'laptop',
#    'large window',
#    'large window',
#    'large window',
#    'living room',
#    'painting',
#    'person',
#    'picture',
#    'picture',
#    'picture',
#    'pillow',
#    'pillow',
#    'room',
#    'rug',
#    'shade',
#    'skyline',
#    'sofa',
#    'someone',
#    'table',
#    'television',
#    'wall',
#    'wall',
#    'window',
#    'window',
#    'window',
#    'window',
#    'window',
#    'window',
#    'windows'],
#   12),
#  (2411935,
#   ['balcony',
#    'bed',
#    'bench',
#    'ceiling',
#    'chair',
#    'chair',
#    'chair',
#    'couch',
#    'curtains',
#    'curtains',
#    'desk',
#    'doors',
#    'drawer',
#    'floor',
#    'handle',
#    'light',
#    'lights',
#    'mirror',
#    'pillow',
#    'pillow',
#    'pillows',
#    'pillows',
#    'room',
#    'shelf',
#    'table',
#    'television',
#    'vase',
#    'view',
#    'wall',
#    'window'],
#   12),
#  (2411518,
#   ['bathroom',
#    'body wash',
#    'can',
#    'canister',
#    'ceiling',
#    'counter',
#    'door',
#    'door handle',
#    'doorway',
#    'edge',
#    'faucet',
#    'floor',
#    'frame',
#    'glass',
#    'handle',
#    'light',
#    'lights',
#    'mirror',
#    'napkin',
#    'rack',
#    'shadow',
#    'shaving cream',
# ...
#    'evelope',
#    'face',
#    'floor',
#    'flower',
#    'flowers',
#    'flowers',
#    'frame',
#    'frame',
#    'frames',
#    'gift bag',
#    'glasses',
#    'hair',
#    'head',
#    'lamp',
#    'lap',
#    'laptop',
#    'mirror',
#    'mirror',
#    'mirror',
#    'mirror',
#    'pants',
#    'pictures',
#    'rail',
#    'rails',
#    'rug',
#    'shade',
#    'shirt',
#    'shoes',
#    'stair case',
#    'staircase',
#    'stairs',
#    'stairway',
#    'steps',
#    'table',
#    'table lamp',
#    'wall',
#    'wall',
#    'wall',
#    'wall',
#    'window',
#    'window',
#    'woman',
#    'wood'],
#   8),
#  (1593105,
#   ['basket',
#    'basket',
#    'bottle',
#    'bottles',
#    'box',
#    'cabinet',
#    'cake',
#    'candle',
#    'candle',
#    'candle',
#    'candles',
#    'carpet',
#    'cat',
#    'cork',
#    'couch',
#    'counter',
#    'ear',
#    'ear',
#    'flower',
#    'fork',
#    'forks',
#    'glass',
#    'pins',
#    'remote',
#    'table',
#    'toy',
#    'water',
#    'whiskers'],
#   8),
#  (1593174,
#   ['air freshener',
#    'bottles',
#    'cabinet',
#    'curtain rod',
#    'door',
#    'doors',
#    'faucet',
#    'faucet',
#    'floor',
#    'handle',
#    'handles',
#    'knobs',
#    'lid',
#    'marble counter',
#    'mirror',
#    'purfume',
#    'seat',
#    'shower',
#    'shower curtain',
#    'shower floor',
#    'shower head',
#    'sink',
#    'tank lid',
#    'toilet',
#    'toilet bowl',
#    'towel',
#    'wall',
#    'wall',
#    'wall'],
#   8),
#  (1593248,
#   ['arm',
#    'arm',
#    'arm',
#    'arm',
#    'arm',
#    'bowl',
#    'button',
#    'chair',
#    'counter',
#    'cupboard',
#    'eyes',
#    'face',
#    'food',
#    'frame',
#    'fridge',
#    'girl',
#    'glasses',
#    'grapes',
#    'hair',
#    'hair',
#    'hair',
#    'hands',
#    'head',
#    'head',
#    'jar',
#    'jersey',
#    'laptop',
#    'man',
#    'microwave',
#    'neck',
#    'necklaces',
#    'paper',
#    'pictures',
#    'plates',
#    'red bowl',
#    'skillet',
#    'stove',
#    'sweater',
#    'sweater',
#    'sweater',
#    'utensils',
#    'woman'],
#   8),
#  (2414697,
#   ['bathroom',
#    'bathtub',
#    'blue',
#    'bottle',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'carpet',
#    'counter',
#    'door',
#    'doorway',
#    'floor',
#    'flusher',
#    'handle',
#    'knob',
#    'knob',
#    'knob',
#    'knob',
#    'molding',
#    'molding',
#    'person',
#    'person',
#    'reflection',
#    'scarf',
#    'shower head',
#    'sink',
#    'suit',
#    'tiles',
#    'toilet',
#    'toilet bowl',
#    'toilet paper',
#    'toilet seat',
#    'wall',
#    'wall'],
#   8),
#  (2414102,
#   ['banana piece',
#    'banana piece',
#    'cup',
#    'dish',
#    'egg',
#    'food',
#    'fork',
#    'glass',
#    'jelly',
#    'juice box',
#    'knife',
#    'mat',
#    'napkin',
#    'plate',
#    'spoon',
#    'tablecloth',
#    'toast',
#    'toast'],
#   8),
#  (2413879,
#   ['basket',
#    'blinds',
#    'blinds',
#    'blinds',
#    'book',
#    'book',
#    'book',
#    'book',
#    'book',
#    'bookshelf',
#    'bottle',
#    'box',
#    'box',
#    'cd',
#    'cd',
#    'controller',
#    'floor',
#    'frame',
#    'hand',
#    'jeans',
#    'kleenex',
#    'laptop',
#    'man',
#    'phone',
#    'plant',
#    'pot',
#    'screen',
#    'shirt',
#    'shredder',
#    'side',
#    'speaker',
#    'spot',
#    'stand',
#    'stereo',
#    'table',
#    'tv',
#    'wall',
#    'wall'],
#   8),
#  (2413195,
#   ['bar',
#    'drawings',
#    'drawings',
#    'drawings',
#    'edit button',
#    'error message',
#    'file button',
#    'floor',
#    'flowers',
#    'graphic',
#    'graphic',
#    'mat',
#    'mat',
#    'rod',
#    'shower curtain',
#    'shower hooks',
#    'stripe',
#    'toilet',
#    'toilet handle',
#    'toilet lid',
#    'toilet seat',
#    'toilet tank top',
#    'towel',
#    'towel',
#    'towel',
#    'towel bar',
#    'towels',
#    'tub',
#    'url address',
#    'vase',
#    'wall',
#    'window'],
#   8),
#  (2412990,
#   ['basket',
#    'bill',
#    'chunks',
#    'cooked',
#    'cutlery',
#    'dish',
#    'fish',
#    'food',
#    'fork',
#    'glass',
#    'glass',
#    'hardwood',
#    'head',
#    'head',
#    'knife',
#    'knife',
#    'knife',
#    'large',
#    'lemon',
#    'lemon',
#    'lemon',
#    'lemon',
#    'meat',
#    'napkin',
#    'napkin',
#    'napkin',
#    'napkin',
#    'napkin',
#    'napkins',
#    'phone',
#    'planks',
#    'plate',
#    'plate',
#    'plate',
#    'plate',
#    'plate',
#    'plate',
#    'red wine',
#    'sauce',
#    'sauce',
#    'seed',
#    'square',
#    'table',
#    'table',
#    'table',
#    'tail',
#    'tail',
#    'tomato sauce',
#    'tomatoes',
#    'vegetables',
#    'vegetables',
#    'vegetables',
#    'vegetables',
#    'wedge',
#    'wine',
#    'wine',
#    'wine'],
#   8),
#  (2412903,
#   ['border',
#    'box',
#    'box',
#    'box',
#    'box',
#    'box',
#    'box',
#    'boxes',
#    'carpet',
#    'ceiling',
#    'curtain',
#    'doorway',
#    'electronics',
#    'face',
#    'face',
#    'glass',
#    'home',
#    'large',
#    'light',
#    'logo',
#    'pane',
#    'picture',
#    'reflection',
#    'reflection',
#    'room',
#    'room',
#    'screen',
#    'shelf',
#    'shelf',
#    'shelf',
#    'shelf',
#    'speaker',
#    'speaker',
#    'stairway',
#    'stand',
#    'stand',
#    'stand',
#    'stand',
#    'step',
#    'step',
#    'system',
#    'toy',
#    'tuffet',
#    'tv',
#    'wall',
#    'window',
#    'window'],
#   8),
#  (2412767,
#   ['air conditioner',
#    'artwork',
#    'bathroom',
#    'bed',
#    'bed spread',
#    'bedroom',
#    'container',
#    'cord',
#    'counter',
#    'curtain',
#    'design',
#    'drawer',
#    'drawer',
#    'drawer',
#    'dresser',
#    'floor',
#    'flower',
#    'ground',
#    'heater',
#    'hotel room',
#    'ice',
#    'outlet',
#    'shelf',
#    'shelf',
#    'shelf',
#    'sink',
#    'telephone',
#    'tile',
#    'top',
#    'towel',
#    'towel',
#    'towels',
#    'tv',
#    'wall',
#    'wall',
#    'wall',
#    'wall',
#    'wall',
#    'window'],
#   8),
#  (2412766,
#   ['arm',
#    'arm',
#    'arm',
#    'arm',
#    'base',
#    'box',
#    'boxes',
#    'cabinets',
#    'ceiling',
#    'chair',
#    'chair',
#    'chair',
#    'chair',
#    'chair',
#    'chair frame',
#    'corner',
#    'cushions',
#    'fabric',
#    'fabric',
#    'floor',
#    'furniture',
#    'green armoire',
#    'item',
#    'lamp',
#    'lamp',
#    'loveseat',
#    'loveseat frame',
#    'post',
#    'purple cushion',
#    'room',
#    'rug',
#    'runner',
#    'scales',
#    'screen',
#    'spots',
#    'swimsuit',
#    'table',
#    'table top',
#    'television',
#    'tv',
#    'wall',
#    'wallpaper',
#    'wallpaper',
#    'white table',
#    'white table',
#    'wood'],
#   8),
#  (2412733,
#   ['bear',
#    'blanket',
#    'blanket',
#    'book',
#    'book',
#    'bookcase',
#    'books',
#    'boy',
#    'boy',
#    'center',
#    'chair',
#    'couch',
#    'couch',
#    'cup',
#    'door',
#    'hair',
#    'lid',
#    'living room',
#    'ottoman',
#    'pajamas',
#    'remote',
#    'straw',
#    'table',
#    'tray'],
#   8),
#  (2412262,
#   ['banana',
#    'banana',
#    'bowl',
#    'chair',
#    'coffee',
#    'egg',
#    'egg',
#    'egg',
#    'food',
#    'fork',
#    'fruit',
#    'glass',
#    'juice',
#    'kitchen',
#    'mug',
#    'orange',
#    'orange',
#    'orange',
#    'orange',
#    'orange',
#    'orange',
#    'plate',
#    'spoon',
#    'table'],
#   8),
#  (2411976,
#   ['basket',
#    'baskets',
#    'border',
#    'box',
#    'box',
#    'can',
#    'cardboard',
#    'cds',
#    'cds',
#    'clock',
#    'corner',
#    'decoration',
#    'design',
#    'design',
#    'door',
#    'floor',
#    'holder',
#    'lights',
#    'mat',
#    'poinsettia',
#    'remote',
#    'remote',
#    'rug',
#    'shelf',
#    'shelf',
#    'shelf',
#    'shelf',
#    'sill',
#    'stand',
#    'stand',
#    'strap',
#    'tree',
#    'tv',
#    'vase',
#    'vent',
#    'wii',
#    'window'],
#   8),
#  (2411707,
#   ['breakfast',
#    'breakfast buffet',
#    'bright light',
#    'butterflies',
#    'cabinet',
#    'candle holder',
#    'candleabra',
#    'ceiling',
#    'centerpieces',
#    'curio',
#    'curtains',
#    'decorations',
#    'dishes',
#    'dishes',
#    'display',
#    'fan',
#    'fans',
#    'flowers',
#    'geranium',
#    'geraniums',
#    'girl',
#    'girl',
#    'girl',
#    'girl',
#    'girl',
#    'girls',
#    'girls hand',
#    'glass',
#    'grey tanktop',
#    'ladies hand',
#    'light',
#    'long brown hair',
#    'lunch',
#    'orange juice',
#    'pink shirt',
#    'place mats',
#    'plate',
#    'plates',
#    'pot',
#    'red hair',
#    'red tanktop',
#    'salt',
#    'saucer',
#    'shakers',
#    'shelf',
#    'shelves',
#    'silverware setting',
#    'spoons',
#    'table',
#    'teacup',
#    'top',
#    'tube top',
#    'yellow'],
#   8),
#  (2411094,
#   ['bath',
#    'bathmat',
#    'bathmat',
#    'bathroom',
#    'bathtub',
#    'blades',
#    'bottle',
#    'cabinet',
#    'ceiling',
#    'chrome',
#    'cloth',
#    'counter',
#    'door',
#    'doors',
#    'drawer',
#    'floor',
#    'flower',
#    'handle',
#    'head',
#    'item',
#    'jets',
#    'large',
#    'light',
#    'lights',
#    'marble',
#    'mat',
#    'rack',
#    'razors',
#    'reflection',
#    'restroom',
#    'shelf',
#    'shower',
#    'soaps',
#    'stall',
#    'three',
#    'tile',
#    'tiled',
#    'toothpaste',
#    'towel',
#    'towel',
#    'towel',
#    'towel',
#    'towels',
#    'tub',
#    'tube',
#    'vanity',
#    'wall',
#    'white',
#    'white'],
#   8),
#  (2410878,
#   ['beans',
#    'bottles',
#    'button',
#    'camera',
#    'design',
#    'design',
#    'dish',
#    'food',
#    'fork',
#    'glass',
#    'glasses',
#    'hair',
#    'hair',
#    'hand',
#    'hands',
#    'head',
#    'knife',
#    'man',
#    'men',
#    'napkin',
#    'nikon',
#    'photo',
#    'plant',
#    'plate',
#    'plate',
#    'pot',
#    'rug',
#    'side',
#    'spoon',
#    'strap',
#    'sweater',
#    'sweater',
#    'table',
#    'wall',
#    'watch',
#    'water',
#    'woman',
#    'wrist'],
#   8),
#  (2410827,
#   ['all',
#    'bar',
#    'ceiling',
#    'drain',
#    'faucet',
#    'floor',
#    'light',
#    'light',
#    'mirror',
#    'shower',
#    'shower head',
#    'sink',
#    'soap',
#    'tiles',
#    'tissue box',
#    'toilet',
#    'toilet paper dispens',
#    'vent',
#    'wall'],
#   8),
#  (2410811,
#   ['balls',
#    'basin',
#    'bathroom',
#    'border',
#    'bottle',
#    'bowl',
#    'cabinet',
#    'curtain',
#    'decoration',
#    'drapes',
#    'edge',
#    'faucet',
#    'fence',
#    'floor',
#    'holder',
#    'jars',
#    'mirror',
#    'pipes',
#    'pitcher',
#    'plumbing',
#    'reflection',
#    'rod',
#    'shelf',
#    'sink',
#    'spots',
#    'sunlight',
#    'tile',
#    'tree',
#    'wall',
#    'window'],
#   8),
#  (2410775,
#   ['books',
#    'box',
#    'cable box',
#    'charger',
#    'curtain',
#    'dvd player',
#    'edge',
#    'electronics',
#    'floor',
#    'hair',
#    'ipod',
#    'lady',
#    'part',
#    'part',
#    'part',
#    'part',
#    'part',
#    'part',
#    'phone',
#    'picture',
#    'pile',
#    'screen',
#    'shelf',
#    'speaker',
#    'speaker',
#    'stack',
#    'stand',
#    'television',
#    'wall',
#    'wall',
#    'wires',
#    'wood'],
#   8),
#  (2410658,
#   ['book',
#    'dvd',
#    'dvd',
#    'dvd',
#    'dvd',
#    'dvds',
#    'dvds',
#    'floor',
#    'frame',
#    'label',
#    'label',
#    'label',
#    'mirror',
#    'movies',
#    'picture',
#    'player',
#    'reflection',
#    'remote',
#    'room',
#    'screen',
#    'shelf',
#    'shelf',
#    'shelf',
#    'shelf',
#    'tapes',
#    'tv',
#    'wall'],
#   8),
#  (2410624,
#   ['bottle',
#    'hanger',
#    'lid',
#    'mirror',
#    'monitor',
#    'outlet',
#    'phone',
#    'rack',
#    'shelf',
#    'sink',
#    'soap',
#    'tissue',
#    'tissue dispenser',
#    'toilet',
#    'toilet lid',
#    'toilet paper',
#    'toilet paper holder',
#    'towel',
#    'towel',
#    'towel',
#    'wall'],
#   8),
#  (2410312,
#   ['basin',
#    'bathroom',
#    'bathtub',
#    'beads',
#    'beige',
#    'bottle',
#    'bottles',
#    'bracelet',
#    'container',
#    'curtain',
#    'dish',
#    'drain',
#    'edge',
#    'eyes',
#    'faucet',
#    'girl',
#    'hair',
#    'hand',
#    'hand',
#    'handle',
#    'holder',
#    'knot',
#    'mirror',
#    'pink',
#    'ring',
#    'shampoo',
#    'shelf',
#    'sink',
#    'tan',
#    'tie',
#    'toothpaste',
#    'top',
#    'toy',
#    'tub',
#    'white'],
#   8),
#  (2410297,
#   ['books',
#    'bottle',
#    'button',
#    'buttons',
#    'cds',
#    'cell phone',
#    'computer',
#    'desk',
#    'drawer',
#    'dvds',
#    'earphones',
#    'hand',
#    'handing',
#    'handle',
#    'man',
#    'monitor',
#    'papers',
#    'rack',
#    'screen',
#    'shelf',
#    'sleeve',
#    'sweater',
#    'tower',
#    'wall'],
#   8),
#  (2410281,
#   ['blinds',
#    'box',
#    'burner',
#    'cabinet',
#    'cabinets',
#    'cabinets',
#    'counter',
#    'cup',
#    'door',
#    'drawers',
#    'faucet',
#    'floor',
#    'freezer',
#    'handle',
#    'handle',
#    'handles',
#    'kitchen',
#    'lights',
#    'lock',
#    'outlets',
#    'oven',
#    'sink',
#    'soap',
#    'stove',
#    'tile',
#    'wall',
#    'window',
#    'window'],
#   8),
#  (2410275,
#   ['ashtray',
#    'beer',
#    'chair',
#    'cigarettes',
#    'family',
#    'fork',
#    'glass',
#    'glasses',
#    'glasses',
#    'hair',
#    'hand',
#    'lettering',
#    'man',
#    'man',
#    'napkin',
#    'painting',
#    'person',
#    'pizza',
#    'pizza',
#    'pizza',
#    'pizza',
#    'plate',
#    'plate',
#    'plate',
#    'plate',
#    'plate',
#    'plate',
#    'plate',
#    'salad',
#    'slice of pizza',
#    'sweater',
#    'sweater',
#    'table',
#    'table cloth',
#    'table cloth',
#    'wall',
#    'wedding band',
#    'wine glass',
#    'woman',
#    'woman',
#    'wrist'],
#   8),
#  (2410267,
#   ['arm',
#    'band',
#    'base',
#    'beverage',
#    'beverage',
#    'beverage',
#    'beverage',
#    'bracelet',
#    'bun',
#    'card',
#    'chair',
#    'cup',
#    'cup',
#    'curtains',
#    'curtains',
#    'dress',
#    'eye glasses',
#    'fingers',
#    'flowers',
#    'food',
#    'frame',
#    'glass',
#    'hair',
#    'hand',
#    'handle',
#    'juice',
#    'juice',
#    'lake',
#    'lenses',
#    'meal',
#    'mug',
#    'napkin',
#    'omelet',
#    'omelet',
#    'plate',
#    'plate',
#    'railing',
#    'scarf',
#    'shaker',
#    'sofa',
#    'table',
#    'tourist',
#    'view',
#    'window',
#    'wrist'],
#   8),
#  (2409930,
#   ['at desk',
#    'brand',
#    'cabinet',
#    'cabinets',
#    'ceiling',
#    'chair',
#    'chair',
#    'chair at',
#    'chairs',
#    'coolers',
#    'copier',
#    'cover',
#    'dark hair',
#    'desk',
#    'desk',
#    'drawers',
#    'equipment',
#    'fridges',
#    'glass',
#    'hair',
#    'handle',
#    'laboratory',
#    'lighting',
#    'man',
#    'man at',
#    'office',
#    'outlet',
#    'person',
#    'phone',
#    'pipe',
#    'piping',
#    'plug',
#    'post',
#    'refrigerator',
#    'rollers',
#    'seats',
#    'shirt',
#    'sunlight',
#    'table',
#    'these are',
#    'these are',
#    'this',
#    'this',
#    'this is',
#    'tile',
#    'wall',
#    'wheels',
#    'windows',
#    'with wheels',
#    'workstation'],
#   8),
#  (2409426,
#   ['bathroom',
#    'bathtub',
#    'blind',
#    'bottle',
#    'corner',
#    'cornet',
#    'cover',
#    'cup',
#    'drawer',
#    'floor',
#    'frame',
#    'mirror',
#    'paint',
#    'rack',
#    'rack',
#    'shelf',
#    'shelf',
#    'sill',
#    'sink',
#    'toilet',
#    'toilet',
#    'toothbrush',
#    'towel',
#    'towel',
#    'towel',
#    'tub',
#    'tumbler',
#    'vanity',
#    'wall',
#    'wall',
#    'wall',
#    'window'],
#   8),
#  (2409420,
#   ['background',
#    'chair',
#    'chair',
#    'chair',
#    'chair',
#    'chair',
#    'chair',
#    'chair',
#    'crouton',
#    'cucumber',
#    'cucumber',
#    'dressing',
#    'foam',
#    'fork',
#    'glass',
#    'knife',
#    'lemon',
#    'lettuce',
#    'lettuce',
#    'meal',
#    'meat',
#    'napkin',
#    'plate',
#    'resturant',
#    'salad',
#    'sandwich',
#    'sandwich',
#    'soft drink',
#    'spoon',
#    'table',
#    'table',
#    'table',
#    'tomato',
#    'tomato',
#    'toothpick',
#    'toothpick',
#    'top',
#    'top',
#    'vegetable'],
#   8),
#  (2409352,
#   ['bag',
#    'box',
#    'burner',
#    'burner',
#    'burner',
#    'burner',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'cabinet',
#    'counter',
#    'counter',
#    'dishwasher',
#    'drawstring',
#    'exhaust hood',
#    'floor',
#    'garbage can',
#    'handle',
#    'handle',
#    'handles',
#    'kitchen',
#    'knife block',
#    'knives',
#    'magnets',
#    'magnets',
#    'magnets',
#    'microwave',
#    'outlet',
#    'outlet',
#    'paper',
#    'plant',
#    'refrigerator',
#    'shelf',
#    'sink',
#    'stove',
#    'towel',
#    'wall'],
#   8),
#  (2409331,
#   ['baby',
#    'basket',
#    'basket',
#    'chair',
#    'child',
#    'child',
#    'cup',
#    'dispenser',
#    'food',
#    'glass',
#    'hair',
#    'lid',
#    'mouth',
#    'pillow',
#    'pitcher',
#    'pizza',
#    'plate',
#    'shirt',
#    'sofa',
#    'table',
#    'wall',
#    'woman'],
#   8),
#  (2409182,
#   ['bananas',
#    'block',
#    'bowl',
#    'cabinet',
#    'cabinet',
#    'carafe',
#    'chair',
#    'chair',
#    'chair',
#    'chair',
#    'chair',
#    'cleaner',
#    'counter',
#    'door',
#    'drawer',
#    'drawers',
#    'faucet',
#    'glass',
#    'handle',
#    'hood',
#    'kitchen',
#    'knives',
#    'knobs',
#    'knobs',
#    'mortar',
#    'oven',
#    'pestle',
#    'reflection',
#    'refrigerator',
#    'sign',
#    'sink',
#    'sink',
#    'stove',
#    'table',
#    'tile',
#    'towl',
#    'towl'],
#   8),
#  ...]

# %%
occurences = [ i[2]  for i in idObjsLen if i[2] >= 0]
d = pd.Series(occurences)
d.value_counts().plot(kind='pie')
#sbs.distplot(occurences)

# %% [markdown]
# ### occurences of remaining words
# This was used to fill negative keywords

# %%
ObjsP = [x[1] for x in idObjsLen]
ObjsP = [y for x in ObjsP for y in x if y not in lines]
FObjsP = Counter(ObjsP).most_common()
FObjsP
# Out:
# [('wall', 18266),
#  ('man', 12480),
#  ('shirt', 11761),
#  ('hand', 8149),
#  ('plate', 7809),
#  ('window', 7542),
#  ('hair', 7209),
#  ('handle', 6900),
#  ('light', 6560),
#  ('person', 6274),
#  ('woman', 6063),
#  ('head', 5848),
#  ('ground', 5713),
#  ('tile', 5648),
#  ('door', 5538),
#  ('bottle', 5170),
#  ('bowl', 4321),
#  ('eye', 4131),
#  ('ear', 3965),
#  ('leg', 3832),
#  ('pillow', 3775),
#  ('picture', 3762),
#  ('flower', 3761),
#  ('counter', 3674),
#  ('nose', 3466),
#  ('button', 3237),
#  ('bag', 3216),
#  ('cabinet', 3205),
#  ('box', 3130),
#  ('face', 3115),
#  ('sign', 3088),
#  ('arm', 3076),
#  ('paper', 3019),
#  ('tree', 2969),
#  ('glasses', 2912),
#  ('lamp', 2729),
#  ('shadow', 2718),
#  ('pants', 2662),
#  ('people', 2413),
#  ('frame', 2363),
#  ('leaf', 2346),
#  ('pizza', 2324),
#  ('edge', 2317),
#  ('shoe', 2290),
#  ('bed', 2286),
#  ('flowers', 2249),
#  ('girl', 2212),
#  ('part', 2205),
#  ('hat', 2175),
#  ('container', 2166),
#  ('towel', 2139),
#  ('banana', 2134),
#  ('leaves', 2117),
#  ('jacket', 2116),
#  ('knob', 2112),
#  ('lid', 2107),
#  ('water', 2102),
#  ('grass', 2102),
#  ('cat', 2097),
#  ('reflection', 2004),
#  ('vase', 2001),
#  ('top', 1990),
#  ('cheese', 1976),
#  ('logo', 1954),
#  ('mouth', 1935),
#  ('boy', 1930),
#  ('faucet', 1924),
#  ('pole', 1899),
#  ('keyboard', 1885),
#  ('drawer', 1874),
#  ('letter', 1855),
#  ('seat', 1812),
#  ('line', 1771),
#  ('finger', 1765),
#  ('bathroom', 1765),
#  ('plant', 1738),
#  ('bread', 1728),
#  ('key', 1683),
#  ('broccoli', 1676),
#  ('number', 1643),
#  ('cake', 1625),
#  ('pot', 1603),
#  ('jeans', 1603),
#  ('sky', 1579),
#  ('cap', 1516),
#  ('design', 1507),
#  ('computer', 1487),
#  ('tray', 1485),
#  ('apple', 1468),
#  ('cord', 1457),
#  ('background', 1456),
#  ('carrot', 1448),
#  ('shorts', 1430),
#  ('orange', 1429),
#  ('stand', 1428),
#  ('spot', 1419),
#  ('writing', 1417),
#  ('sauce', 1417),
#  ('lights', 1404),
#  ('eyes', 1395),
#  ('foot', 1390),
#  ('blanket', 1385),
#  ('phone', 1371),
#  ('dog', 1371),
#  ('meat', 1367),
#  ('wheel', 1349),
#  ('trees', 1342),
#  ('stripe', 1340),
#  ('fence', 1301),
#  ('tomato', 1268),
#  ('candle', 1254),
#  ('legs', 1249),
#  ('tail', 1245),
#  ('tiles', 1242),
#  ('board', 1237),
#  ('dish', 1235),
#  ('paw', 1227),
#  ('stem', 1214),
#  ('shoes', 1209),
#  ('corner', 1186),
#  ('hands', 1181),
#  ('wood', 1160),
#  ('bananas', 1145),
#  ('neck', 1127),
#  ('hole', 1118),
#  ('cloth', 1103),
#  ('donut', 1084),
#  ('mouse', 1077),
#  ('watch', 1075),
#  ('tie', 1072),
#  ('rack', 1046),
#  ('label', 1043),
#  ('bear', 1043),
#  ('wrist', 1025),
#  ('sticker', 1009),
#  ('photo', 1001),
#  ('crust', 1001),
#  ('lady', 999),
#  ('collar', 997),
#  ('sweater', 976),
#  ('sandwich', 972),
#  ('base', 951),
#  ('outlet', 941),
#  ('brick', 941),
#  ('can', 934),
#  ('wine', 934),
#  ('back', 919),
#  ('ball', 917),
#  ('ring', 914),
#  ('dress', 907),
#  ('vegetable', 893),
#  ('cabinets', 890),
#  ('umbrella', 888),
#  ('cushion', 870),
#  ('letters', 867),
#  ('blinds', 852),
#  ('stripes', 847),
#  ('object', 846),
#  ('pipe', 834),
#  ('bar', 827),
#  ('onion', 823),
#  ('buttons', 821),
#  ('white', 820),
#  ('remote', 818),
#  ('speaker', 814),
#  ('coat', 813),
#  ('tag', 811),
#  ('dirt', 807),
#  ('shade', 805),
#  ('windows', 798),
#  ('lettuce', 795),
#  ('pepper', 788),
#  ('sunglasses', 787),
#  ('tv', 777),
#  ('camera', 751),
#  ('child', 751),
#  ('tablecloth', 745),
#  ('surface', 745),
#  ('trim', 743),
#  ('sleeve', 736),
#  ('strap', 726),
#  ('lines', 725),
#  ('wire', 718),
#  ('liquid', 716),
#  ('cover', 713),
#  ('helmet', 708),
#  ('rock', 703),
#  ('slice', 702),
#  ('controller', 691),
#  ('feet', 688),
#  ('post', 684),
#  ('word', 679),
#  ('piece', 667),
#  ('frosting', 655),
#  ('pepperoni', 655),
#  ('pen', 652),
#  ('handles', 646),
#  ('fur', 644),
#  ('bird', 639),
#  ('bottles', 638),
#  ('sock', 637),
#  ('pattern', 634),
#  ('field', 632),
#  ('pillows', 631),
#  ('bun', 619),
#  ('suitcase', 613),
#  ('whiskers', 608),
#  ('guy', 605),
#  ('necklace', 603),
#  ('mug', 602),
#  ('lettering', 597),
#  ('bracelet', 590),
#  ('a', 590),
#  ('headboard', 583),
#  ('snow', 576),
#  ('item', 574),
#  ('carrots', 574),
#  ('side', 572),
#  ('circle', 571),
#  ('plates', 568),
#  ('countertop', 568),
#  ('racket', 568),
#  ('papers', 563),
#  ('case', 562),
#  ('bottom', 561),
#  ('roof', 558),
#  ('luggage', 557),
#  ('player', 556),
#  ('suit', 554),
#  ('vent', 553),
#  ('train', 553),
#  ('backpack', 551),
#  ('ears', 544),
#  ('beard', 536),
#  ('toilet paper', 536),
#  ('sheet', 534),
#  ('tire', 533),
#  ('dot', 533),
#  ('glove', 526),
#  ('thumb', 522),
#  ('knobs', 521),
#  ('burner', 520),
#  ('belt', 520),
#  ('panel', 519),
#  ('tank', 515),
#  ('bush', 512),
#  ('black', 512),
#  ('items', 512),
#  ('branch', 511),
#  ('clouds', 511),
#  ('house', 510),
#  ('doorway', 510),
#  ('railing', 508),
#  ('uniform', 508),
#  ('hot dog', 507),
#  ('pocket', 507),
#  ('straw', 505),
#  ('square', 502),
#  ('chicken', 500),
#  ('metal', 499),
#  ('utensil', 497),
#  ('words', 495),
#  ('numbers', 494),
#  ('fingers', 493),
#  ('wires', 487),
#  ('clothes', 485),
#  ('counter top', 480),
#  ('mushroom', 477),
#  ('topping', 474),
#  ('court', 473),
#  ('hinge', 470),
#  ('teeth', 469),
#  ('drink', 468),
#  ('animal', 468),
#  ('salad', 464),
#  ('drawers', 462),
#  ('keys', 461),
#  ('flag', 457),
#  ('band', 453),
#  ('eyeglasses', 452),
#  ('display', 452),
#  ('plants', 444),
#  ('wheels', 442),
#  ('doors', 441),
#  ('beer', 440),
#  ('spots', 433),
#  ('boat', 429),
#  ('potato', 428),
#  ('drain', 427),
#  ('roll', 427),
#  ('bucket', 426),
#  ('teddy bear', 421),
#  ('scarf', 421),
#  ('earring', 420),
#  ('fireplace', 419),
#  ('stool', 419),
#  ('egg', 418),
#  ('elbow', 416),
#  ('switch', 414),
#  ('olive', 414),
#  ('decoration', 413),
#  ('apples', 412),
#  ('rail', 410),
#  ('tomatoes', 405),
#  ('doughnut', 405),
#  ('bat', 404),
#  ('paint', 402),
#  ('magnet', 402),
#  ('socks', 402),
#  ('bike', 398),
#  ('pictures', 397),
#  ('fabric', 396),
#  ('star', 394),
#  ('onions', 393),
#  ('blade', 392),
#  ('baby', 391),
#  ('trunk', 391),
#  ('rim', 390),
#  ('platform', 390),
#  ('cloud', 389),
#  ('walls', 388),
#  ('ribbon', 387),
#  ('purse', 387),
#  ('t-shirt', 386),
#  ('rice', 386),
#  ('skateboard', 385),
#  ('tub', 382),
#  ('tip', 382),
#  ('rocks', 382),
#  ('giraffe', 380),
#  ('icing', 373),
#  ('oranges', 372),
#  ('trash can', 372),
#  ('apron', 371),
#  ('comforter', 368),
#  ('skirt', 367),
#  ('stick', 364),
#  ('pitcher', 360),
#  ('stone', 360),
#  ('petal', 357),
#  ('toppings', 356),
#  ('light switch', 355),
#  ('saucer', 353),
#  ('coffee', 351),
#  ('knee', 347),
#  ('shoulder', 346),
#  ('plastic', 346),
#  ('dresser', 346),
#  ('brush', 343),
#  ('game', 341),
#  ('string', 338),
#  ('green', 336),
#  ('chest', 336),
#  ('patch', 335),
#  ('cupboard', 334),
#  ('strawberry', 333),
#  ('arms', 332),
#  ('cable', 331),
#  ('nail', 331),
#  ('silverware', 330),
#  ('chain', 329),
#  ('border', 328),
#  ('vest', 327),
#  ('the', 327),
#  ('cups', 326),
#  ('eyebrow', 326),
#  ('lemon', 325),
#  ('truck', 325),
#  ('ketchup', 324),
#  ('red', 323),
#  ('donuts', 323),
#  ('sausage', 322),
#  ('bin', 321),
#  ('boxes', 320),
#  ('road', 319),
#  ('plug', 317),
#  ('art', 314),
#  ('bacon', 313),
#  ('cords', 312),
#  ('statue', 311),
#  ('brown', 311),
#  ('blue', 311),
#  ('name', 310),
#  ('tower', 309),
#  ('cutting board', 308),
#  ('this', 308),
#  ('text', 307),
#  ('pile', 307),
#  ('image', 306),
#  ('hook', 305),
#  ('light fixture', 299),
#  ('lamp shade', 298),
#  ('spinach', 298),
#  ('cupcake', 297),
#  ('dishes', 297),
#  ('clothing', 296),
#  ('rope', 296),
#  ('fixture', 296),
#  ('horse', 295),
#  ('cabinet door', 294),
#  ('crumbs', 293),
#  ('potatoes', 293),
#  ('stack', 289),
#  ('area', 288),
#  ('front', 286),
#  ('magazine', 286),
#  ('menu', 284),
#  ('zipper', 284),
#  ('bow', 283),
#  ('pillar', 282),
#  ('bunch', 282),
#  ('crumb', 281),
#  ('nightstand', 280),
#  ('peppers', 280),
#  ('screw', 278),
#  ('pane', 277),
#  ('pastry', 275),
#  ('cucumber', 275),
#  ('row', 274),
#  ('meal', 273),
#  ('tracks', 273),
#  ('placemat', 272),
#  ('wing', 272),
#  ('chin', 271),
#  ('bicycle', 271),
#  ('ledge', 271),
#  ('table top', 270),
#  ('pad', 270),
#  ('bolt', 270),
#  ('jersey', 270),
#  ('chocolate', 269),
#  ('card', 269),
#  ('branches', 269),
#  ('banner', 264),
#  ('roman numeral', 263),
#  ('grape', 262),
#  ('column', 262),
#  ('bushes', 261),
#  ('sheets', 261),
#  ('bricks', 261),
#  ('cart', 261),
#  ('paws', 261),
#  ('juice', 261),
#  ('headlight', 261),
#  ('net', 260),
#  ('men', 260),
#  ('blue jeans', 259),
#  ('mark', 259),
#  ('scene', 258),
#  ('sunlight', 258),
#  ('tape', 256),
#  ('slat', 256),
#  ('french fry', 255),
#  ('restaurant', 254),
#  ('dots', 254),
#  ('mustard', 253),
#  ('grapes', 252),
#  ('lips', 252),
#  ('boot', 252),
#  ('blue shirt', 251),
#  ('block', 251),
#  ('cookie', 251),
#  ('body', 251),
#  ('bedspread', 250),
#  ('stairs', 249),
#  ('print', 249),
#  ('hood', 249),
#  ('fingernail', 249),
#  ('lap', 248),
#  ('napkins', 248),
#  ('smile', 246),
#  ('section', 246),
#  ('fries', 246),
#  ('heart', 245),
#  ('seats', 244),
#  ('fruits', 243),
#  ('sneaker', 243),
#  ('ham', 243),
#  ('sheep', 243),
#  ('sprinkles', 242),
#  ('fish', 241),
#  ('cow', 240),
#  ('skin', 239),
#  ('dessert', 239),
#  ('lampshade', 238),
#  ('couple', 238),
#  ('step', 237),
#  ('outfit', 236),
#  ('kid', 236),
#  ('bookcase', 235),
#  ('hoodie', 235),
#  ('soup', 231),
#  ('spectator', 230),
#  ('beam', 229),
#  ('stain', 228),
#  ('cream', 228),
#  ('numeral', 228),
#  ('eggs', 227),
#  ('crack', 227),
#  ('holes', 227),
#  ('rose', 225),
#  ('flooring', 224),
#  ('beak', 224),
#  ('wallpaper', 223),
#  ('sneakers', 223),
#  ('sugar', 222),
#  ('group', 222),
#  ('pickle', 222),
#  ('artwork', 221),
#  ('tennis court', 218),
#  ('hill', 217),
#  ('bowls', 216),
#  ('remote control', 216),
#  ('beverage', 216),
#  ('bags', 216),
#  ('advertisement', 216),
#  ('end', 215),
#  ('butter', 214),
#  ('furniture', 213),
#  ('platter', 213),
#  ('symbol', 212),
#  ('coffee cup', 211),
#  ('air', 211),
#  ('corn', 210),
#  ('crate', 210),
#  ('catcher', 210),
#  ('arrow', 209),
#  ('newspaper', 208),
#  ('beans', 208),
#  ('headphones', 207),
#  ('dial', 207),
#  ('soda', 206),
#  ('sandal', 206),
#  ('boots', 206),
#  ('stuffed animal', 205),
#  ('mattress', 205),
#  ('lock', 204),
#  ('machine', 203),
#  ('bean', 203),
#  ('balloon', 202),
#  ('blender', 201),
#  ('tank top', 201),
#  ('wristband', 199),
#  ('water bottle', 198),
#  ('wine bottle', 198),
#  ('shaker', 198),
#  ('strawberries', 198),
#  ('windshield', 197),
#  ('chips', 196),
#  ('candy', 196),
#  ('graffiti', 196),
#  ('spatula', 195),
#  ('trash', 195),
#  ('white shirt', 195),
#  ('baseboard', 194),
#  ('baseball player', 194),
#  ('blouse', 193),
#  ('concrete', 193),
#  ('ponytail', 193),
#  ('drawing', 193),
#  ('magnets', 193),
#  ('hotdog', 193),
#  ('frisbee', 192),
#  ('containers', 191),
#  ('stands', 190),
#  ('picture frame', 189),
#  ('fry', 189),
#  ('black shirt', 189),
#  ('grill', 189),
#  ('doll', 189),
#  ('olives', 188),
#  ('mushrooms', 188),
#  ('mouse pad', 187),
#  ('silver', 187),
#  ('stems', 187),
#  ('figurine', 186),
#  ('hose', 186),
#  ('mountain', 185),
#  ('control', 185),
#  ('foil', 184),
#  ('mustache', 184),
#  ('gloves', 184),
#  ('noodles', 184),
#  ('sand', 184),
#  ('batter', 183),
#  ('notebook', 182),
#  ('tongue', 182),
#  ('socket', 181),
#  ('right hand', 181),
#  ('white plate', 181),
#  ('wrapper', 180),
#  ('brown hair', 179),
#  ('microphone', 178),
#  ('wii', 178),
#  ('pipes', 177),
#  ('hanger', 177),
#  ('tennis racket', 177),
#  ('yellow', 177),
#  ('umpire', 175),
#  ('coaster', 174),
#  ('kite', 174),
#  ('sprinkle', 174),
#  ('note', 173),
#  ('french fries', 173),
#  ('center', 173),
#  ('shadows', 172),
#  ('left hand', 172),
#  ('gate', 172),
#  ('door knob', 172),
#  ('spectators', 172),
#  ('right', 170),
#  ('milk', 170),
#  ('tattoo', 170),
#  ('coffee maker', 168),
#  ('sweatshirt', 168),
#  ('mantle', 168),
#  ('door handle', 168),
#  ('pineapple', 168),
#  ('objects', 168),
#  ('left', 168),
#  ('whisker', 168),
#  ('tree trunk', 167),
#  ('poles', 167),
#  ('icon', 166),
#  ('salt shaker', 166),
#  ('pieces', 166),
#  ('armrest', 165),
#  ('lighting', 165),
#  ('ladder', 165),
#  ('carton', 165),
#  ('slices', 164),
#  ('log', 163),
#  ('headband', 163),
#  ('stuff', 163),
#  ('tube', 162),
#  ('bars', 162),
#  ('knives', 162),
#  ('bulb', 162),
#  ('track', 162),
#  ('seeds', 162),
#  ('store', 161),
#  ('inside', 160),
#  ('planter', 159),
#  ('grout', 159),
#  ('veggies', 159),
#  ('coffee mug', 158),
#  ('radiator', 158),
#  ('crowd', 158),
#  ('cooler', 158),
#  ('forehead', 157),
#  ('seed', 157),
#  ('spices', 157),
#  ('package', 156),
#  ('device', 156),
#  ('computer mouse', 155),
#  ('knot', 154),
#  ('plank', 153),
#  ('sandals', 153),
#  ('basin', 153),
#  ('basil', 153),
#  ('towel rack', 152),
#  ('doorknob', 152),
#  ('diamond', 151),
#  ('blind', 149),
#  ('pasta', 149),
#  ('plane', 149),
#  ('pie', 149),
#  ('mane', 149),
#  ('cone', 148),
#  ('appliance', 147),
#  ('two', 147),
#  ('designs', 147),
#  ('cabbage', 147),
#  ('ice', 146),
#  ('window sill', 146),
#  ('airplane', 146),
#  ('blueberry', 146),
#  ('red shirt', 145),
#  ('pencil', 144),
#  ('tent', 144),
#  ('petals', 143),
#  ('green leaves', 143),
#  ('blonde hair', 143),
#  ('hoof', 143),
#  ('figure', 143),
#  ('pots', 142),
#  ('emblem', 142),
#  ('mask', 142),
#  ('greens', 142),
#  ('white tile', 142),
#  ('electrical outlet', 141),
#  ('steps', 141),
#  ('cushions', 141),
#  ('decorations', 140),
#  ('pavement', 140),
#  ('muffin', 140),
#  ('printer', 139),
#  ('glare', 139),
#  ('soap dispenser', 139),
#  ('feathers', 139),
#  ('marks', 139),
#  ('strip', 138),
#  ('canister', 138),
#  ('opening', 138),
#  ('stickers', 138),
#  ('station', 138),
#  ('shrimp', 137),
#  ('left eye', 137),
#  ('photograph', 137),
#  ('bouquet', 137),
#  ('engine', 137),
#  ('toothpick', 136),
#  ('chip', 136),
#  ('black hair', 135),
#  ('molding', 135),
#  ('material', 135),
#  ('nut', 135),
#  ('night stand', 134),
#  ('buildings', 134),
#  ('balcony', 134),
#  ('vanity', 134),
#  ('cheek', 134),
#  ('cauliflower', 133),
#  ('outside', 133),
#  ('salt', 133),
#  ('plastic bag', 132),
#  ('wrinkle', 132),
#  ('ramp', 132),
#  ('tennis ball', 132),
#  ('seasoning', 132),
#  ('celery', 132),
#  ('wrinkles', 131),
#  ('horn', 131),
#  ('zebra', 131),
#  ('women', 130),
#  ('left ear', 130),
#  ('pens', 129),
#  ('laces', 129),
#  ('ornament', 129),
#  ('dugout', 129),
#  ('signs', 128),
#  ('tongs', 128),
#  ('cross', 128),
#  ('tooth', 128),
#  ('color', 127),
#  ('candle holder', 127),
#  ('toast', 127),
#  ('calendar', 126),
#  ('bubble', 126),
#  ('cherry', 126),
#  ('ceiling light', 125),
#  ('sill', 125),
#  ('structure', 125),
#  ('cardboard', 125),
#  ('garbage can', 124),
#  ('surfboard', 124),
#  ('arm rest', 123),
#  ('vehicle', 123),
#  ('pink', 123),
#  ('slats', 123),
#  ('support', 122),
#  ('baseball', 122),
#  ('bristles', 122),
#  ('pea', 121),
#  ('lime', 121),
#  ('paper plate', 121),
#  ('beef', 121),
#  ('cables', 120),
#  ('mousepad', 120),
#  ('clip', 120),
#  ('backsplash', 120),
#  ('path', 120),
#  ('oven door', 120),
#  ('lanyard', 120),
#  ('light reflection', 120),
#  ('right ear', 120),
#  ('cookies', 120),
#  ('marker', 119),
#  ('latch', 119),
#  ('buckle', 119),
#  ('squash', 119),
#  ('time', 118),
#  ('burners', 118),
#  ('gravel', 118),
#  ('pair', 118),
#  ('trashcan', 117),
#  ('right eye', 117),
#  ('door frame', 117),
#  ('paper towel', 117),
#  ('noodle', 117),
#  ('tool', 117),
#  ('binder', 116),
#  ('barrel', 116),
#  ('lip', 116),
#  ('berry', 116),
#  ('nuts', 116),
#  ('sleeves', 115),
#  ('forest', 115),
#  ('eyebrows', 115),
#  ('peel', 115),
#  ('mitt', 114),
#  ('tap', 114),
#  ('bleachers', 114),
#  ('avocado', 114),
#  ('panels', 113),
#  ('guitar', 112),
#  ('range', 112),
#  ('garnish', 112),
#  ('cement', 112),
#  ('canopy', 111),
#  ('skis', 111),
#  ('condiments', 111),
#  ('tarp', 110),
#  ('deck', 110),
#  ('herbs', 110),
#  ('hay', 110),
#  ('ski', 110),
#  ('brick wall', 109),
#  ('wii remote', 109),
#  ('female', 109),
#  ('bangs', 108),
#  ('wooden', 108),
#  ('bell', 108),
#  ('clock face', 108),
#  ('heater', 107),
#  ('pear', 107),
#  ('divider', 107),
#  ('pastries', 107),
#  ('bagel', 107),
#  ('roman numerals', 107),
#  ('chef', 106),
#  ('dough', 106),
#  ('plaque', 106),
#  ('visor', 106),
#  ('side table', 105),
#  ('closet', 105),
#  ('scale', 105),
#  ('pedestal', 105),
#  ('bridge', 105),
#  ('nails', 104),
#  ('stall', 104),
#  ('parsley', 104),
#  ('desktop', 103),
#  ('charger', 103),
#  ('goggles', 103),
#  ('game controller', 103),
#  ('distance', 103),
#  ('cans', 103),
#  ('players', 103),
#  ('baseball cap', 103),
#  ('watermelon', 103),
#  ('berries', 103),
#  ('beads', 103),
#  ('pizza slice', 102),
#  ('controls', 102),
#  ('green pepper', 102),
#  ('patio', 101),
#  ('hallway', 101),
#  ('sticks', 101),
#  ('grate', 101),
#  ('cuff', 101),
#  ('entertainment center', 100),
#  ('flame', 100),
#  ('chopsticks', 100),
#  ('space', 100),
#  ('tines', 100),
#  ('straps', 100),
#  ('wrist band', 100),
#  ('he', 100),
#  ('toe', 100),
#  ('wallet', 99),
#  ('white wall', 99),
#  ('roses', 99),
#  ('tea', 99),
#  ('ice cream', 99),
#  ('half', 99),
#  ('produce', 99),
#  ('floor tile', 98),
#  ('sponge', 98),
#  ('animals', 98),
#  ('pepper shaker', 98),
#  ('green shirt', 98),
#  ('pans', 98),
#  ('glaze', 98),
#  ('packet', 97),
#  ('quilt', 97),
#  ('bracket', 97),
#  ('pumpkin', 97),
#  ('bumper', 97),
#  ('tennis', 97),
#  ('fringe', 96),
#  ('floor lamp', 96),
#  ('cupboards', 96),
#  ('mountains', 96),
#  ('home plate', 96),
#  ('belly', 96),
#  ('brocolli', 95),
#  ('speck', 95),
#  ('green leaf', 95),
#  ('beams', 94),
#  ('sculpture', 94),
#  ('armchair', 94),
#  ('drinks', 94),
#  ('arch', 94),
#  ('leash', 94),
#  ('bead', 94),
#  ('cereal', 93),
#  ('hinges', 93),
#  ('coffee pot', 93),
#  ('map', 93),
#  ('doughnuts', 93),
#  ('facial hair', 93),
#  ('syrup', 93),
#  ('gravy', 93),
#  ('herb', 93),
#  ('ipod', 93),
#  ('layer', 93),
#  ('dark hair', 92),
#  ('black pants', 92),
#  ('peas', 92),
#  ('graphic', 92),
#  ('middle', 92),
#  ('grain', 92),
#  ('strings', 92),
#  ('stalk', 92),
#  ('folder', 91),
#  ('jars', 91),
#  ('tv stand', 91),
#  ('weeds', 91),
#  ('squares', 91),
#  ('christmas tree', 91),
#  ('claw', 91),
#  ('condiment', 91),
#  ('fire', 90),
#  ('palm tree', 90),
#  ('male', 90),
#  ('blades', 90),
#  ('blue sky', 90),
#  ('foliage', 89),
#  ('lemons', 89),
#  ('knees', 89),
#  ('stadium', 89),
#  ('wii controller', 89),
#  ('numerals', 89),
#  ('badge', 88),
#  ('light bulb', 88),
#  ('stains', 88),
#  ('foam', 88),
#  ('video game', 88),
#  ('barrier', 88),
#  ('tissue box', 87),
#  ('handbag', 87),
#  ('book shelf', 87),
#  ('tables', 87),
#  ('vases', 87),
#  ('breakfast', 87),
#  ('oil', 87),
#  ('name tag', 86),
#  ('paneling', 86),
#  ('butter knife', 86),
#  ('dinner', 86),
#  ('booth', 86),
#  ('equipment', 86),
#  ('globe', 85),
#  ('dryer', 85),
#  ('flour', 85),
#  ('beer bottle', 85),
#  ('markings', 85),
#  ('children', 84),
#  ('interior', 84),
#  ('garlic', 84),
#  ('spoons', 84),
#  ('horns', 84),
#  ('portion', 84),
#  ('floors', 83),
#  ('staircase', 83),
#  ('robe', 83),
#  ('eye glasses', 83),
#  ('bath tub', 83),
#  ('bed frame', 83),
#  ('necktie', 83),
#  ('toes', 83),
#  ('spice', 83),
#  ('short', 83),
#  ('tomato sauce', 83),
#  ('set', 82),
#  ('radio', 82),
#  ('red wine', 82),
#  ('waist', 82),
#  ('keypad', 82),
#  ('windowsill', 82),
#  ('character', 82),
#  ('duck', 82),
#  ('license plate', 81),
#  ('balls', 81),
#  ('orange juice', 81),
#  ('lunch', 81),
#  ('gray', 81),
#  ('cupcakes', 81),
#  ('alarm clock', 80),
#  ...]

# %% [markdown]
# ## Save filtered images in file
# We will save in the filtered images IDs

# %%
imageIDs = [x[0] for x in idObjsLen2]
l  = open(writingPath,'w')
for i,x in enumerate(imageIDs):
  if i != 0 : 
    l.write('\n')
  l.write(str(x))
l.close
# Out:
# <function TextIOWrapper.close>

# %% [markdown]
# ## Get QA and save them.

# %% [markdown]
# ### download visual genome questions answers

# %%
# !wget -P '$download_QAs_path' http://visualgenome.org/static/data/dataset/question_answers.json.zip
os.chdir(download_QAs_path)
# !unzip question_answers.json
# Out:
# --2019-02-28 16:32:33--  http://visualgenome.org/static/data/dataset/question_answers.json.zip
# Resolving visualgenome.org (visualgenome.org)... 54.87.32.87
# Connecting to visualgenome.org (visualgenome.org)|54.87.32.87|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24776315 (24M) [application/zip]
# Saving to: ‘/content/question_answers.json.zip’
#
# question_answers.js 100%[===================>]  23.63M  6.70MB/s    in 5.4s
#
# 2019-02-28 16:32:38 (4.37 MB/s) - ‘/content/question_answers.json.zip’ saved [24776315/24776315]
#
# Archive:  question_answers.json.zip
#   inflating: question_answers.json

# %% [markdown]
# ### Filter questions answers
# We take questions answers that correspond to filtered images. We save that in a json file

# %%
with open(writingPath) as p : 
  imageIDs = [int(x.strip()) for x in p.readlines() if x != '']
  
Int_imageIDs = [int(x) for x in imageIDs]
QAs_path = os.path.join(download_QAs_path, 'question_answers.json')
with open(QAs_path, 'r') as g : 
  QAs = json.load(g)
i = 0
for x in QAs : 
  if i == 10:
    break
  print(x)
  i +=1
objs = []
count = 0
for im in QAs : 
  image_id = im['id']
  qas = im['qas']
  
  if image_id in Int_imageIDs:
    count +=1
    filtered_QAs = [{'question' : x['question'], 'answer' : x['answer']} for x in qas ]
    obj = {
      'image_id' : image_id,
      'QAs' : filtered_QAs
    }
    objs.append(obj)
print(count)
with open(save_qas_file , 'w') as f : 
   json.dump(objs, f)
# Out:
# {'id': 1, 'qas': [{'a_objects': [], 'question': 'What color is the clock?', 'image_id': 1, 'qa_id': 986768, 'answer': 'Green.', 'q_objects': []}, {'a_objects': [], 'question': 'How many people are there?', 'image_id': 1, 'qa_id': 986769, 'answer': 'Two.', 'q_objects': []}, {'a_objects': [], 'question': "What color is the man's shirt?", 'image_id': 1, 'qa_id': 986772, 'answer': 'Red.', 'q_objects': []}, {'a_objects': [], 'question': 'What are the men doing?', 'image_id': 1, 'qa_id': 986777, 'answer': 'Interacting.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the white work truck?', 'image_id': 1, 'qa_id': 986780, 'answer': 'Parked on the street.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the guy wearing?', 'image_id': 1, 'qa_id': 986781, 'answer': 'A red shirt.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the black sign?', 'image_id': 1, 'qa_id': 986782, 'answer': 'On the front of the building.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the guy holding a hand?', 'image_id': 1, 'qa_id': 986783, 'answer': "To the man's chin.", 'q_objects': []}, {'a_objects': [], 'question': 'What color is the clock?', 'image_id': 1, 'qa_id': 986787, 'answer': 'Green.', 'q_objects': []}, {'a_objects': [], 'question': 'What color shirt is the man wearing?', 'image_id': 1, 'qa_id': 986788, 'answer': 'Red.', 'q_objects': []}, {'a_objects': [], 'question': 'What color jacket is the man to the right wearing?', 'image_id': 1, 'qa_id': 986789, 'answer': 'Grey.', 'q_objects': []}, {'a_objects': [], 'question': 'How many men are there?', 'image_id': 1, 'qa_id': 986793, 'answer': 'Two.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the building closest to the men?', 'image_id': 1, 'qa_id': 986794, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'What color shoes is the man in the grey hoodie wearing?', 'image_id': 1, 'qa_id': 986795, 'answer': 'Brown.', 'q_objects': []}, {'a_objects': [], 'question': 'What kind of material is the building closest made of?', 'image_id': 1, 'qa_id': 986797, 'answer': 'Brick.', 'q_objects': []}, {'a_objects': [], 'question': "What is on the man's face wearing the red shirt?", 'image_id': 1, 'qa_id': 986798, 'answer': 'Glasses.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the sidewalk made of?', 'image_id': 1, 'qa_id': 986800, 'answer': 'Bricks.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are the cars parked?', 'image_id': 1, 'qa_id': 986801, 'answer': 'Along the edge of the street.', 'q_objects': []}, {'a_objects': [], 'question': "What color are the man's pants wearing the red shirt?", 'image_id': 1, 'qa_id': 986802, 'answer': 'Black.', 'q_objects': []}, {'a_objects': [], 'question': "What color is the man's hoodie?", 'image_id': 1, 'qa_id': 986804, 'answer': 'Gray.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the building behind the man in the red shirt?', 'image_id': 1, 'qa_id': 986805, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the truck?', 'image_id': 1, 'qa_id': 986806, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the tall building on the left made out of?', 'image_id': 1, 'qa_id': 986807, 'answer': 'Bricks.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are the trees?', 'image_id': 1, 'qa_id': 986808, 'answer': 'Next to the people.', 'q_objects': []}, {'a_objects': [], 'question': 'What color are the trees?', 'image_id': 1, 'qa_id': 986809, 'answer': 'Green.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the jumper the man is wearing?', 'image_id': 1, 'qa_id': 986812, 'answer': 'Grey.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the tree?', 'image_id': 1, 'qa_id': 986815, 'answer': 'Shadows.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the white vehicle?', 'image_id': 1, 'qa_id': 986816, 'answer': 'Parked.', 'q_objects': []}, {'a_objects': [], ' ...
# {'id': 2, 'qas': [{'a_objects': [], 'question': 'What color is the car?', 'image_id': 2, 'qa_id': 986934, 'answer': 'Red.', 'q_objects': []}, {'a_objects': [], 'question': 'What color are the trees?', 'image_id': 2, 'qa_id': 986935, 'answer': 'Green.', 'q_objects': []}, {'a_objects': [], 'question': 'What has lots of glass windows?', 'image_id': 2, 'qa_id': 986936, 'answer': 'The building.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the guy doing?', 'image_id': 2, 'qa_id': 986937, 'answer': 'Walking.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the man doing?', 'image_id': 2, 'qa_id': 986938, 'answer': 'Crossing the street.', 'q_objects': []}, {'a_objects': [], 'question': 'What does the crosswalk sign say?', 'image_id': 2, 'qa_id': 986939, 'answer': 'Walk.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the car closest to the man?', 'image_id': 2, 'qa_id': 986940, 'answer': 'Red.', 'q_objects': []}, {'a_objects': [], 'question': "What is on the man's back?", 'image_id': 2, 'qa_id': 986941, 'answer': 'A backpack.', 'q_objects': []}, {'a_objects': [], 'question': 'What color are the lines in the road?', 'image_id': 2, 'qa_id': 986942, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the sidewalk made out of?', 'image_id': 2, 'qa_id': 986943, 'answer': 'Bricks.', 'q_objects': []}, {'a_objects': [], 'question': "What color are the man's shoes?", 'image_id': 2, 'qa_id': 986944, 'answer': 'Black.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the man crossing?', 'image_id': 2, 'qa_id': 986945, 'answer': 'At the crosswalk.', 'q_objects': []}, {'a_objects': [], 'question': "What color is the man's hair?", 'image_id': 2, 'qa_id': 986946, 'answer': 'Black.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are cars?', 'image_id': 2, 'qa_id': 986948, 'answer': 'Parked on the street.', 'q_objects': []}, {'a_objects': [], 'question': 'Who has on black clothing?', 'image_id': 2, 'qa_id': 986949, 'answer': 'A man.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are trees?', 'image_id': 2, 'qa_id': 986950, 'answer': 'Lining the street.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are posters?', 'image_id': 2, 'qa_id': 986951, 'answer': 'On a traffic light.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are many windows?', 'image_id': 2, 'qa_id': 986952, 'answer': 'On a building.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are shadows?', 'image_id': 2, 'qa_id': 986953, 'answer': 'On the road.', 'q_objects': []}, {'a_objects': [], 'question': 'Who is wearing a backpack?', 'image_id': 2, 'qa_id': 986954, 'answer': 'The man.', 'q_objects': []}, {'a_objects': [], 'question': 'Who is about to cross the street?', 'image_id': 2, 'qa_id': 986955, 'answer': 'A man.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are trees without leaves?', 'image_id': 2, 'qa_id': 986956, 'answer': 'In the distance.', 'q_objects': []}, {'a_objects': [], 'question': 'Who has black hair?', 'image_id': 2, 'qa_id': 986957, 'answer': 'A man.', 'q_objects': []}, {'a_objects': [], 'question': 'When in the day is this?', 'image_id': 2, 'qa_id': 986958, 'answer': 'Afternoon.', 'q_objects': []}, {'a_objects': [], 'question': 'Who is walking?', 'image_id': 2, 'qa_id': 986959, 'answer': 'Young man.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the man wearing?', 'image_id': 2, 'qa_id': 986960, 'answer': 'Black.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the man?', 'image_id': 2, 'qa_id': 986961, 'answer': 'City street.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the white paint there for?', 'image_id': 2, 'qa_id': 986962, 'answer': 'Crosswalk.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the man doing?', 'image_id': 2, 'qa_id': 986964, 'answer': 'Walking.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the traffic like?', 'image_id': 2, 'qa_id': 986965, 'answer': ...
# {'id': 3, 'qas': [{'a_objects': [], 'question': 'Where is the photo taken?', 'image_id': 3, 'qa_id': 966135, 'answer': 'An office.', 'q_objects': []}, {'a_objects': [], 'question': 'Where was this photo taken?', 'image_id': 3, 'qa_id': 966489, 'answer': 'In a office.', 'q_objects': []}, {'a_objects': [], 'question': 'What style hair does the woman have?', 'image_id': 3, 'qa_id': 987124, 'answer': 'Ponytail.', 'q_objects': []}, {'a_objects': [], 'question': "What color is the woman's hair?", 'image_id': 3, 'qa_id': 987125, 'answer': 'Black.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the woman looking at?', 'image_id': 3, 'qa_id': 987126, 'answer': 'The computer.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the woman doing?', 'image_id': 3, 'qa_id': 987127, 'answer': 'Sitting down.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is computer tower?', 'image_id': 3, 'qa_id': 987128, 'answer': 'Under desk.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the file cabinet?', 'image_id': 3, 'qa_id': 987129, 'answer': 'Next to desk.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the girl doing?', 'image_id': 3, 'qa_id': 987130, 'answer': 'Sitting.', 'q_objects': []}, {'a_objects': [], 'question': 'What kind of edge is on desk?', 'image_id': 3, 'qa_id': 987131, 'answer': 'Curved.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are the cables?', 'image_id': 3, 'qa_id': 987133, 'answer': 'On floor.', 'q_objects': []}, {'a_objects': [], 'question': 'How many outlets are in the wall?', 'image_id': 3, 'qa_id': 987135, 'answer': 'Four.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the bag?', 'image_id': 3, 'qa_id': 987136, 'answer': 'Black.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the calendar?', 'image_id': 3, 'qa_id': 987137, 'answer': 'On wall.', 'q_objects': []}, {'a_objects': [], 'question': 'Why has the monitor been switched off?', 'image_id': 3, 'qa_id': 987138, 'answer': 'No one is working.', 'q_objects': []}, {'a_objects': [], 'question': 'What color shirt is the woman wearing?', 'image_id': 3, 'qa_id': 987139, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'What color shirt is the woman wearing?', 'image_id': 3, 'qa_id': 987141, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'Why is there a partition between the workers?', 'image_id': 3, 'qa_id': 987142, 'answer': 'Privacy.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the telephone?', 'image_id': 3, 'qa_id': 987143, 'answer': 'Black.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the bag on the desk?', 'image_id': 3, 'qa_id': 987144, 'answer': 'Black.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the woman doing at the computer?', 'image_id': 3, 'qa_id': 987145, 'answer': 'Working.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the computer?', 'image_id': 3, 'qa_id': 987146, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the partition?', 'image_id': 3, 'qa_id': 987147, 'answer': 'Calendar.', 'q_objects': []}, {'a_objects': [], 'question': 'What is pictured?', 'image_id': 3, 'qa_id': 987148, 'answer': 'Cubicles.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is this scene?', 'image_id': 3, 'qa_id': 987149, 'answer': 'Office.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the lady?', 'image_id': 3, 'qa_id': 987151, 'answer': 'Upper right.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the wall?', 'image_id': 3, 'qa_id': 987152, 'answer': 'Pictures.', 'q_objects': []}, {'a_objects': [], 'question': 'What is hanging from the wall?', 'image_id': 3, 'qa_id': 987154, 'answer': 'Chords.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the left?', 'image_id': 3, 'qa_id': 987155, 'answer': 'Cabinet.', 'q_objects': []}, {'a_objects': [], 'question': 'What shape is the desk?', 'image_id': 3, 'qa ...
# {'id': 4, 'qas': [{'a_objects': [], 'question': 'What is on the curtains?', 'image_id': 4, 'qa_id': 987278, 'answer': 'Sailboats.', 'q_objects': []}, {'a_objects': [], 'question': 'What color are the curtains?', 'image_id': 4, 'qa_id': 987280, 'answer': 'Blue.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the pillow?', 'image_id': 4, 'qa_id': 987281, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'Where was the photo taken?', 'image_id': 4, 'qa_id': 987282, 'answer': 'In a room.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the couch?', 'image_id': 4, 'qa_id': 987283, 'answer': 'Purple.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the table made out of?', 'image_id': 4, 'qa_id': 987284, 'answer': 'Glass.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the couch?', 'image_id': 4, 'qa_id': 987285, 'answer': 'A teddy bear.', 'q_objects': []}, {'a_objects': [], 'question': 'What time is it?', 'image_id': 4, 'qa_id': 987286, 'answer': 'Afternoon.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the bear sitting on?', 'image_id': 4, 'qa_id': 987287, 'answer': 'Couch.', 'q_objects': []}, {'a_objects': [], 'question': 'How many chairs are pictured?', 'image_id': 4, 'qa_id': 987288, 'answer': 'Two.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is a pillow?', 'image_id': 4, 'qa_id': 987289, 'answer': 'On the couch.', 'q_objects': []}, {'a_objects': [], 'question': 'What color are the curtains?', 'image_id': 4, 'qa_id': 987290, 'answer': 'Blue.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the carpet?', 'image_id': 4, 'qa_id': 987291, 'answer': 'On the floor.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the couch?', 'image_id': 4, 'qa_id': 987292, 'answer': 'Purple.', 'q_objects': []}, {'a_objects': [], 'question': 'What is glass?', 'image_id': 4, 'qa_id': 987293, 'answer': 'The table.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is a painting?', 'image_id': 4, 'qa_id': 987294, 'answer': 'Against the wall.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is a lamp?', 'image_id': 4, 'qa_id': 987295, 'answer': 'In the corner.', 'q_objects': []}, {'a_objects': [], 'question': 'What is white?', 'image_id': 4, 'qa_id': 987296, 'answer': 'Pillow.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is a teddy bear?', 'image_id': 4, 'qa_id': 987297, 'answer': 'In front of the pillow.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the teddy bear?', 'image_id': 4, 'qa_id': 987298, 'answer': 'On the purple sofa.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the black lamp?', 'image_id': 4, 'qa_id': 987299, 'answer': 'In the corner behind the sofa.', 'q_objects': []}, {'a_objects': [], 'question': 'What kind of top does the table have?', 'image_id': 4, 'qa_id': 987300, 'answer': 'Glass.', 'q_objects': []}, {'a_objects': [], 'question': 'How many chairs are at the table?', 'image_id': 4, 'qa_id': 987301, 'answer': 'Two.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the printed theme on the curtains?', 'image_id': 4, 'qa_id': 987302, 'answer': 'Boats.', 'q_objects': []}, {'a_objects': [], 'question': 'What color are the chair seats at the table?', 'image_id': 4, 'qa_id': 987303, 'answer': 'Blue.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the lamp in the corner?', 'image_id': 4, 'qa_id': 987304, 'answer': 'Black and silver.', 'q_objects': []}, {'a_objects': [], 'question': 'What kind of flooring is in front of sliding glass door?', 'image_id': 4, 'qa_id': 987305, 'answer': 'Checkered wood.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the rug?', 'image_id': 4, 'qa_id': 987306, 'answer': 'Grayish purple.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the framed picture?', 'image_id': 4, 'qa_id': 987307, 'answer': 'Propped against the wall.', 'q_objects': []}, {'a_objects': [], 'question': 'Where i ...
# {'id': 5, 'qas': [{'a_objects': [], 'question': 'Where was this photo taken?', 'image_id': 5, 'qa_id': 966490, 'answer': 'In a home office.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are the cables?', 'image_id': 5, 'qa_id': 987452, 'answer': 'On floor.', 'q_objects': []}, {'a_objects': [], 'question': 'How are the chairs?', 'image_id': 5, 'qa_id': 987453, 'answer': 'Empty.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are the books?', 'image_id': 5, 'qa_id': 987454, 'answer': 'On shelf.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the wall?', 'image_id': 5, 'qa_id': 987455, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the chair?', 'image_id': 5, 'qa_id': 987457, 'answer': 'Brown.', 'q_objects': []}, {'a_objects': [], 'question': 'Why is the computer monitor dark?', 'image_id': 5, 'qa_id': 987458, 'answer': "It's off.", 'q_objects': []}, {'a_objects': [], 'question': 'What line the shelf?', 'image_id': 5, 'qa_id': 987459, 'answer': 'Books.', 'q_objects': []}, {'a_objects': [], 'question': "Why isn't anyone in the room?", 'image_id': 5, 'qa_id': 987460, 'answer': 'The door is locked.', 'q_objects': []}, {'a_objects': [], 'question': 'Why is the room empty?', 'image_id': 5, 'qa_id': 987461, 'answer': 'Door is locked.', 'q_objects': []}, {'a_objects': [], 'question': 'What is above the computer?', 'image_id': 5, 'qa_id': 987462, 'answer': 'An air conditioner.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the wall?', 'image_id': 5, 'qa_id': 987464, 'answer': 'Cream.', 'q_objects': []}, {'a_objects': [], 'question': 'What are on the shelves?', 'image_id': 5, 'qa_id': 987465, 'answer': 'Books.', 'q_objects': []}, {'a_objects': [], 'question': 'What is metal outside the window?', 'image_id': 5, 'qa_id': 987466, 'answer': 'A railing.', 'q_objects': []}, {'a_objects': [], 'question': 'What is brown leaning against the wall?', 'image_id': 5, 'qa_id': 987467, 'answer': 'A cork board.', 'q_objects': []}, {'a_objects': [], 'question': 'How many chairs are there?', 'image_id': 5, 'qa_id': 987468, 'answer': '2.', 'q_objects': []}, {'a_objects': [], 'question': 'What the device on the desk?', 'image_id': 5, 'qa_id': 987469, 'answer': 'Computer.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are the books?', 'image_id': 5, 'qa_id': 987470, 'answer': 'Shelf.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the shelf?', 'image_id': 5, 'qa_id': 987471, 'answer': 'Wall.', 'q_objects': []}, {'a_objects': [], 'question': 'How lit is the room?', 'image_id': 5, 'qa_id': 987473, 'answer': 'Dim.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the cleanliness of the room?', 'image_id': 5, 'qa_id': 987475, 'answer': 'Not clean.', 'q_objects': []}, {'a_objects': [], 'question': 'What is above the desk?', 'image_id': 5, 'qa_id': 987476, 'answer': 'Heater.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the floor made of?', 'image_id': 5, 'qa_id': 987477, 'answer': 'Wood.', 'q_objects': []}, {'a_objects': [], 'question': 'What is shining through the window?', 'image_id': 5, 'qa_id': 987478, 'answer': 'Light.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the desk?', 'image_id': 5, 'qa_id': 987479, 'answer': 'Computer.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the bulletin board?', 'image_id': 5, 'qa_id': 987481, 'answer': 'Against wall.', 'q_objects': []}, {'a_objects': [], 'question': 'What number of chairs is there?', 'image_id': 5, 'qa_id': 987483, 'answer': '2.', 'q_objects': []}, {'a_objects': [], 'question': 'When in a day is it?', 'image_id': 5, 'qa_id': 987484, 'answer': 'Afternoon.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are the books?', 'image_id': 5, 'qa_id': 987485, 'answer': 'Shelf.', 'q_objects': []}, {'a_objects': [], 'question': 'What is above the desk?', 'image_id': 5, 'qa_id': 987486, 'answer': 'Heater.', 'q_objects': []}, {'a_objects': [], 'questio ...
# {'id': 6, 'qas': [{'a_objects': [], 'question': 'Where was this photo taken?', 'image_id': 6, 'qa_id': 966491, 'answer': 'In a dining room.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the apple?', 'image_id': 6, 'qa_id': 987644, 'answer': 'Red.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the table made out of?', 'image_id': 6, 'qa_id': 987646, 'answer': 'Granite.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the fork?', 'image_id': 6, 'qa_id': 987647, 'answer': 'Silver.', 'q_objects': []}, {'a_objects': [], 'question': 'What is in the glass?', 'image_id': 6, 'qa_id': 987648, 'answer': 'Milk.', 'q_objects': []}, {'a_objects': [], 'question': 'What color lid is on the bottle?', 'image_id': 6, 'qa_id': 987649, 'answer': 'Red.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the plate?', 'image_id': 6, 'qa_id': 987650, 'answer': 'A fork.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the table top?', 'image_id': 6, 'qa_id': 987652, 'answer': 'Black.', 'q_objects': []}, {'a_objects': [], 'question': 'What type of bowl is it?', 'image_id': 6, 'qa_id': 987654, 'answer': 'Wooden.', 'q_objects': []}, {'a_objects': [], 'question': 'What kind of countertop is it?', 'image_id': 6, 'qa_id': 987655, 'answer': 'Granite.', 'q_objects': []}, {'a_objects': [], 'question': 'What kind of fruit is on the table?', 'image_id': 6, 'qa_id': 987656, 'answer': 'An apple.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the table made of?', 'image_id': 6, 'qa_id': 987657, 'answer': 'Wood.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the white plate?', 'image_id': 6, 'qa_id': 987658, 'answer': 'The white plate is empty.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the black bag?', 'image_id': 6, 'qa_id': 987659, 'answer': 'On the table.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the counter?', 'image_id': 6, 'qa_id': 987661, 'answer': 'A brown bowl.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the counter?', 'image_id': 6, 'qa_id': 987662, 'answer': 'A plastic bowl.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the counter?', 'image_id': 6, 'qa_id': 987663, 'answer': 'A metal bowl.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the counter?', 'image_id': 6, 'qa_id': 987664, 'answer': 'A bag of food.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the apple?', 'image_id': 6, 'qa_id': 987665, 'answer': 'It is red.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the water bottle?', 'image_id': 6, 'qa_id': 987666, 'answer': 'Red and white.', 'q_objects': []}, {'a_objects': [], 'question': 'What is in the bag?', 'image_id': 6, 'qa_id': 987668, 'answer': 'Baby carrots.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the shape of bowl?', 'image_id': 6, 'qa_id': 987670, 'answer': 'Circular.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the apple?', 'image_id': 6, 'qa_id': 987671, 'answer': 'Red.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the apple?', 'image_id': 6, 'qa_id': 987672, 'answer': 'On table.', 'q_objects': []}, {'a_objects': [], 'question': 'What is in the glass?', 'image_id': 6, 'qa_id': 987673, 'answer': 'Milk.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the pot holder?', 'image_id': 6, 'qa_id': 987675, 'answer': 'Black.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the apple?', 'image_id': 6, 'qa_id': 987676, 'answer': 'Red.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the plate?', 'image_id': 6, 'qa_id': 987677, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the dish made of?', 'image_id': 6, 'qa_id': 987678, 'answer': 'Plastic.', 'q_objects': []}, {'a_objects': [], 'question': 'What utensil is on the plate?', 'image_id': 6, 'qa_id': 987680, 'answer': 'A fork.', 'q_objects': []}, {'a_objec ...
# {'id': 7, 'qas': [{'a_objects': [], 'question': 'Who is sitting in the chair?', 'image_id': 7, 'qa_id': 987854, 'answer': 'A young lady with black hair.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the whiteboard?', 'image_id': 7, 'qa_id': 987855, 'answer': 'Writing.', 'q_objects': []}, {'a_objects': [], 'question': 'What is turned on?', 'image_id': 7, 'qa_id': 987856, 'answer': 'The desktop monitor.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the woman looking at?', 'image_id': 7, 'qa_id': 987857, 'answer': 'The monitor.', 'q_objects': []}, {'a_objects': [], 'question': 'What has been drawn on the board?', 'image_id': 7, 'qa_id': 987858, 'answer': 'Equations.', 'q_objects': []}, {'a_objects': [], 'question': "How is the woman's expression?", 'image_id': 7, 'qa_id': 987859, 'answer': 'Happy.', 'q_objects': []}, {'a_objects': [], 'question': "What color are the woman's pants?", 'image_id': 7, 'qa_id': 987860, 'answer': 'Blue.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the wall?', 'image_id': 7, 'qa_id': 987861, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'How is the neatness of the desk?', 'image_id': 7, 'qa_id': 987862, 'answer': 'Cluttered.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the board on the wall?', 'image_id': 7, 'qa_id': 987863, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the computer mouse?', 'image_id': 7, 'qa_id': 987864, 'answer': 'On the mouse pad.', 'q_objects': []}, {'a_objects': [], 'question': 'What type of computer is shown?', 'image_id': 7, 'qa_id': 987865, 'answer': 'Desk top.', 'q_objects': []}, {'a_objects': [], 'question': "What color is the woman's shirt?", 'image_id': 7, 'qa_id': 987866, 'answer': 'Brown.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the laptop?', 'image_id': 7, 'qa_id': 987867, 'answer': 'Black.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the woman wearing?', 'image_id': 7, 'qa_id': 987868, 'answer': 'Beige sweater.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the window?', 'image_id': 7, 'qa_id': 987869, 'answer': 'Brown.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the folder on the other desk?', 'image_id': 7, 'qa_id': 987870, 'answer': 'Black.', 'q_objects': []}, {'a_objects': [], 'question': 'Who is sitting at the desk?', 'image_id': 7, 'qa_id': 987871, 'answer': 'A woman in a gray shirt and blue jeans.', 'q_objects': []}, {'a_objects': [], 'question': 'Who is sitting in the chair?', 'image_id': 7, 'qa_id': 987872, 'answer': 'A woman.', 'q_objects': []}, {'a_objects': [], 'question': 'What are the walkman and headphones for?', 'image_id': 7, 'qa_id': 987873, 'answer': 'Listening.', 'q_objects': []}, {'a_objects': [], 'question': 'What food is on the desk?', 'image_id': 7, 'qa_id': 987875, 'answer': 'Cheese crackers and water.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the board?', 'image_id': 7, 'qa_id': 987876, 'answer': 'Red writing.', 'q_objects': []}, {'a_objects': [], 'question': 'Who is in the chair?', 'image_id': 7, 'qa_id': 987877, 'answer': 'Lady with cream colored shirt.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are reflections?', 'image_id': 7, 'qa_id': 987879, 'answer': 'On the window.', 'q_objects': []}, {'a_objects': [], 'question': 'What is turned on?', 'image_id': 7, 'qa_id': 987880, 'answer': 'Computer screen.', 'q_objects': []}, {'a_objects': [], 'question': 'Who is looking at the computer?', 'image_id': 7, 'qa_id': 987881, 'answer': 'A woman.', 'q_objects': []}, {'a_objects': [], 'question': 'Who has black hair?', 'image_id': 7, 'qa_id': 987882, 'answer': 'The woman.', 'q_objects': []}, {'a_objects': [], 'question': 'How many people are in the room?', 'image_id': 7, 'qa_id': 987883, 'answer': 'One.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is a beige phone?', 'image_id': 7, 'qa_id': 987884, 'answer': 'On t ...
# {'id': 8, 'qas': [{'a_objects': [], 'question': 'Where is the photo taken?', 'image_id': 8, 'qa_id': 966286, 'answer': 'In a house.', 'q_objects': []}, {'a_objects': [], 'question': 'What has been turned on?', 'image_id': 8, 'qa_id': 987958, 'answer': 'A monitor.', 'q_objects': []}, {'a_objects': [], 'question': 'What color are the drawers?', 'image_id': 8, 'qa_id': 987960, 'answer': 'Grey.', 'q_objects': []}, {'a_objects': [], 'question': "Where is the man's hand?", 'image_id': 8, 'qa_id': 987961, 'answer': 'On the keyboard.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the man wearing?', 'image_id': 8, 'qa_id': 987962, 'answer': 'A black and white t-shirt.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is a picture?', 'image_id': 8, 'qa_id': 987963, 'answer': 'Taped up on the wall.', 'q_objects': []}, {'a_objects': [], 'question': 'Who is sitting at the computer?', 'image_id': 8, 'qa_id': 987964, 'answer': 'A boy with glasses.', 'q_objects': []}, {'a_objects': [], 'question': 'What is taped up on the wall?', 'image_id': 8, 'qa_id': 987965, 'answer': 'A photograph.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the bulletin board?', 'image_id': 8, 'qa_id': 987967, 'answer': 'Papers.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the man holding?', 'image_id': 8, 'qa_id': 987968, 'answer': 'His chin.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the man looking at?', 'image_id': 8, 'qa_id': 987969, 'answer': 'His computer.', 'q_objects': []}, {'a_objects': [], 'question': 'What does the white folder contain?', 'image_id': 8, 'qa_id': 987970, 'answer': 'Papers.', 'q_objects': []}, {'a_objects': [], 'question': 'What is fixed to the wall?', 'image_id': 8, 'qa_id': 987971, 'answer': 'A painting.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the shelf?', 'image_id': 8, 'qa_id': 987972, 'answer': 'Books.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the guy wearing face?', 'image_id': 8, 'qa_id': 987973, 'answer': 'Glasses.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the guys right hand?', 'image_id': 8, 'qa_id': 987974, 'answer': 'On the keyboard.', 'q_objects': []}, {'a_objects': [], 'question': 'What does the man have on?', 'image_id': 8, 'qa_id': 987975, 'answer': 'Glasses.', 'q_objects': []}, {'a_objects': [], 'question': 'What color are the drawers?', 'image_id': 8, 'qa_id': 987976, 'answer': 'Grey.', 'q_objects': []}, {'a_objects': [], 'question': 'What does the cpu have on top of it?', 'image_id': 8, 'qa_id': 987977, 'answer': 'Books.', 'q_objects': []}, {'a_objects': [], 'question': 'How many people are in the picture?', 'image_id': 8, 'qa_id': 987978, 'answer': '1.', 'q_objects': []}, {'a_objects': [], 'question': 'What color are the desk drawers?', 'image_id': 8, 'qa_id': 987980, 'answer': 'Gray.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the picture taken?', 'image_id': 8, 'qa_id': 987981, 'answer': 'Office.', 'q_objects': []}, {'a_objects': [], 'question': 'Who is in the picture?', 'image_id': 8, 'qa_id': 987983, 'answer': 'The man.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the chair?', 'image_id': 8, 'qa_id': 987984, 'answer': 'Blue.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are the books?', 'image_id': 8, 'qa_id': 987985, 'answer': 'On the shelves.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are the coffee cups?', 'image_id': 8, 'qa_id': 987986, 'answer': '2 on desks, 1 on shelf.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the cd at?', 'image_id': 8, 'qa_id': 987987, 'answer': 'Right desk.', 'q_objects': []}, {'a_objects': [], 'question': 'What color wood are the bookshelves made out of?', 'image_id': 8, 'qa_id': 987988, 'answer': 'Light wood.', 'q_objects': []}, {'a_objects': [], 'question': 'What are on the bookshelves?', 'image_id': 8, 'qa_id': 987989, 'answer': 'Books.', 'q_objects': []}, {'a_objects': [], 'question': 'What  ...
# {'id': 9, 'qas': [{'a_objects': [], 'question': 'Where was this picture taken?', 'image_id': 9, 'qa_id': 984453, 'answer': 'Office.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the monitor?', 'image_id': 9, 'qa_id': 988104, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'What covers the windows?', 'image_id': 9, 'qa_id': 988106, 'answer': 'Venetian blinds.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the monitor on the desk?', 'image_id': 9, 'qa_id': 988107, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'Where was the picture taken?', 'image_id': 9, 'qa_id': 988108, 'answer': 'In an office.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the ceiling?', 'image_id': 9, 'qa_id': 988109, 'answer': 'Lights.', 'q_objects': []}, {'a_objects': [], 'question': 'How many chairs are there?', 'image_id': 9, 'qa_id': 988110, 'answer': '6.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are the wooden bookshelves?', 'image_id': 9, 'qa_id': 988111, 'answer': 'Against the wall.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are the computer monitors?', 'image_id': 9, 'qa_id': 988112, 'answer': 'On the desk.', 'q_objects': []}, {'a_objects': [], 'question': 'How many laptop computers are there?', 'image_id': 9, 'qa_id': 988113, 'answer': '1.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the blue trash can?', 'image_id': 9, 'qa_id': 988114, 'answer': 'Beside the desk.', 'q_objects': []}, {'a_objects': [], 'question': 'Who works in the office?', 'image_id': 9, 'qa_id': 988115, 'answer': 'Employees.', 'q_objects': []}, {'a_objects': [], 'question': 'What is to the left of the bookshelves?', 'image_id': 9, 'qa_id': 988116, 'answer': 'Computer monitor.', 'q_objects': []}, {'a_objects': [], 'question': 'How many windows are there?', 'image_id': 9, 'qa_id': 988117, 'answer': '3.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the tall object against the wall?', 'image_id': 9, 'qa_id': 988119, 'answer': 'Bookshelf.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the wall?', 'image_id': 9, 'qa_id': 988120, 'answer': 'Green.', 'q_objects': []}, {'a_objects': [], 'question': 'What color are the desks?', 'image_id': 9, 'qa_id': 988121, 'answer': 'White.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the blue container for?', 'image_id': 9, 'qa_id': 988122, 'answer': 'Recycling.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the square object on the wall?', 'image_id': 9, 'qa_id': 988123, 'answer': 'Corkboard.', 'q_objects': []}, {'a_objects': [], 'question': 'How many chairs are visible?', 'image_id': 9, 'qa_id': 988124, 'answer': '6.', 'q_objects': []}, {'a_objects': [], 'question': 'What is on the very bottom of the chairs that makes the chairs mobile?', 'image_id': 9, 'qa_id': 988125, 'answer': 'Wheels.', 'q_objects': []}, {'a_objects': [], 'question': 'What material are the chairs made of?', 'image_id': 9, 'qa_id': 988127, 'answer': 'Fabric and plastic.', 'q_objects': []}, {'a_objects': [], 'question': 'How big is the office window?', 'image_id': 9, 'qa_id': 988128, 'answer': 'From floor to ceiling.', 'q_objects': []}, {'a_objects': [], 'question': 'What are all over the table?', 'image_id': 9, 'qa_id': 988129, 'answer': 'Papers.', 'q_objects': []}, {'a_objects': [], 'question': 'What is hanging on the wall?', 'image_id': 9, 'qa_id': 988130, 'answer': 'A wooden frame.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the square hanging on the wall?', 'image_id': 9, 'qa_id': 988131, 'answer': 'Bulletin board.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the newer computer monitor?', 'image_id': 9, 'qa_id': 988134, 'answer': 'On the desk.', 'q_objects': []}, {'a_objects': [], 'question': 'What has wheels?', 'image_id': 9, 'qa_id': 988135, 'answer': 'The computer chair.', 'q_objects': []}, {'a_objects': [], 'question': 'Why is there stuff all over the  ...
# {'id': 10, 'qas': [{'a_objects': [], 'question': 'Where are the cpus being stored?', 'image_id': 10, 'qa_id': 988197, 'answer': 'Under the desk.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the coat on the chair?', 'image_id': 10, 'qa_id': 988198, 'answer': 'Red and blue.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the wall?', 'image_id': 10, 'qa_id': 988199, 'answer': 'Green.', 'q_objects': []}, {'a_objects': [], 'question': 'What is hanging on the wall?', 'image_id': 10, 'qa_id': 988200, 'answer': 'Cork board.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the jacket?', 'image_id': 10, 'qa_id': 988201, 'answer': 'The chair.', 'q_objects': []}, {'a_objects': [], 'question': 'How many computer towers are shown?', 'image_id': 10, 'qa_id': 988202, 'answer': 'Two.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the bookshelf?', 'image_id': 10, 'qa_id': 988203, 'answer': 'Against the wall.', 'q_objects': []}, {'a_objects': [], 'question': 'What is stacked on the lower half of the shelf?', 'image_id': 10, 'qa_id': 988204, 'answer': 'Papers.', 'q_objects': []}, {'a_objects': [], 'question': 'What is strewn across the desk?', 'image_id': 10, 'qa_id': 988205, 'answer': 'Papers.', 'q_objects': []}, {'a_objects': [], 'question': 'How is the floor covered?', 'image_id': 10, 'qa_id': 988206, 'answer': 'With carpeting.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are computer wires shown?', 'image_id': 10, 'qa_id': 988207, 'answer': 'Under the desk.', 'q_objects': []}, {'a_objects': [], 'question': 'How many monitors are there?', 'image_id': 10, 'qa_id': 988209, 'answer': 'Two.', 'q_objects': []}, {'a_objects': [], 'question': 'Where are the computer towers?', 'image_id': 10, 'qa_id': 988210, 'answer': 'On floor.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the cork board?', 'image_id': 10, 'qa_id': 988211, 'answer': 'On wall.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the coffee mug?', 'image_id': 10, 'qa_id': 988212, 'answer': 'On table.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the bookshelf made of?', 'image_id': 10, 'qa_id': 988213, 'answer': 'Wood.', 'q_objects': []}, {'a_objects': [], 'question': 'What color shirt is the man wearing?', 'image_id': 10, 'qa_id': 988215, 'answer': 'Gray.', 'q_objects': []}, {'a_objects': [], 'question': 'How many stuffed animals are on the bookshelf?', 'image_id': 10, 'qa_id': 988216, 'answer': 'One.', 'q_objects': []}, {'a_objects': [], 'question': 'Who is sitting in the chair?', 'image_id': 10, 'qa_id': 988217, 'answer': 'A man.', 'q_objects': []}, {'a_objects': [], 'question': 'How many shelves are there in the bookshelf?', 'image_id': 10, 'qa_id': 988218, 'answer': 'Six.', 'q_objects': []}, {'a_objects': [], 'question': 'Who is in this photo?', 'image_id': 10, 'qa_id': 988219, 'answer': 'A man at his desk.', 'q_objects': []}, {'a_objects': [], 'question': 'Where is the blue coffee cup?', 'image_id': 10, 'qa_id': 988220, 'answer': 'On the desk.', 'q_objects': []}, {'a_objects': [], 'question': 'What is the man on the right doing?', 'image_id': 10, 'qa_id': 988222, 'answer': 'Using a computer.', 'q_objects': []}, {'a_objects': [], 'question': "How does the man's work area look?", 'image_id': 10, 'qa_id': 988223, 'answer': 'Messy.', 'q_objects': []}, {'a_objects': [], 'question': "What color is the man's shirt?", 'image_id': 10, 'qa_id': 988225, 'answer': 'Gray.', 'q_objects': []}, {'a_objects': [], 'question': 'What colors are the jackets on the chair?', 'image_id': 10, 'qa_id': 988226, 'answer': 'Red and blue.', 'q_objects': []}, {'a_objects': [], 'question': 'Who left the computer monitor on?', 'image_id': 10, 'qa_id': 988227, 'answer': 'The new girl.', 'q_objects': []}, {'a_objects': [], 'question': 'What color is the jacket on the chair?', 'image_id': 10, 'qa_id': 988228, 'answer': 'Red and blue.', 'q_objects': []}, {'a_objects': [], 'question': 'What is against the wall? ...
# 29317
